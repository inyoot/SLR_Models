# %% [markdown]
# <a href="https://colab.research.google.com/github/inyoot/SLR_Models/blob/main/MATH5001_Project_Report_SLR_E1_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sign Language Recognition Neuro-Symbolic Model
# ## HAND Self-Organize Meaning
#
# **Name:** Iwan Sandjaja
#
# **Date:** May 15, 2026
#
# **Course:** MATH 5001 - Mathematical Foundations of Deep Learning

# %% [markdown]
# ## Introduction of Sign Language Recognition Research
#
# ### The Dynamism and Complexity of Sign Language
#
# The multimodal communication system of sign language is essentially different from spoken or written languages, as its meaning is inherently rooted in physical, dynamic action. Machine learning models are unable to depend on a single, isolated data stream, such as audio or text, in order to accurately capture and interpret these languages. Rather, they are required to synthesize intricate, concurrent inputs. This necessitates the surveillance of nuanced facial landmarks and broader body posture signals, in addition to high-fidelity hand pose-tracking to map the precise shape and movement of the digits. Every one of these components possesses significant semantic significance; a minor adjustment to the trajectory of a hand or the position of an eyebrow can completely transform the meaning of a sentence. Consequently, the development of effective recognition systems necessitates the implementation of highly advanced monitoring technologies that are capable of interpreting this complex physical vocabulary in real time.
#
# ### AI as an Equalizer, Enhancer, and Enabler
#
# The development of sign language recognition systems is of profound social and ethical significance, in addition to the technical milestones. The most effective approach to implementing artificial intelligence in this domain is to explicitly design it as an equalizer, enhancer, and enabler for the Deaf and Hard of Hearing (DHoH) community. AI should be perceived as a critical link that eliminates ubiquitous communication barriers in commonplace environments, such as healthcare, education, the workplace, and customer service, rather than merely as a novel technological experiment. AI can cultivate a more inclusive society by empowering individuals, enhancing their independence, and providing seamless, real-time translation and accessible interfaces, ensuring that communication access is a universal standard.
#
# ### Making Way for the Next Generation of Interfaces
#
# Additionally, overcoming the immense complexities of sign language recognition establishes a strong foundational framework for a diverse range of futuristic applications. Directly pertinent to the broader evolution of human-computer interaction are the spatial tracking technologies and machine learning models necessary to accurately decode nuanced human gestures. For example, this technology serves as the foundation for spatial computing concepts such as "writing in the air," which enables users to interact with digital text and environments without the use of physical keyboards or touchscreens. Furthermore, these developments are indispensable for the seamless integration of Virtual Reality (VR) and Augmented Reality (AR), in which intuitive, hands-free gesture control is indispensable for the development of immersive digital experiences. Ultimately, the resolution of the challenges associated with sign language recognition not only promotes human accessibility but also serves as the catalyst for the next significant frontier of technological innovation.

# %% [markdown]
# ### Survey of the State of The Art of Sign Language Recognition
#
# Due to their capacity to analyze sequential and multimodal data, including multiple-camera video sequences, Hidden Markov Models (HMMs) have gained significant popularity in the field of Sign Language Recognition (SLR). Input devices, feature extraction methods, and a recognizer comprise the standard architecture of an SLR system. The HMM recognizer classifies input, which can range from video files and RGB cameras to depth sensors and electronic gloves, after feature extraction using computer vision or dimension reduction techniques.
#
# The evolution of HMMs in SLR is divided into five chronological episodes, with the first episode being Classical HMMs, which were largely reliant on early computer vision techniques. RGB cameras and color-coded mittens were employed by early systems to monitor hand movements for datasets such as Filipino Sign Language. Depth-sensing technologies, such as the Microsoft Kinect and stereo cameras, were introduced in the second episode, Extended HMMs. Weighted Hidden Markov Models (WHMMs) were created by researchers to resolve the differences between various signers. These models assign varying weights to sign samples based on training errors, thereby enhancing the accuracy of recognition.
#
# The subsequent episodes, beginning with HMMs and Machine Learning, compared and combined HMMs with neural networks and Support Vector Machines, thereby expanding the capabilities of HMMs through advanced computational techniques. The HMMs and Sensor Fusion episode followed, which enhanced 3D feature extraction by integrating data from multiple sensors. For example, the episode involved the integration of Leap Motion devices with Kinect cameras using early and late data fusion techniques. Lastly, the Automatic HMMs and Big Data episode concentrated on the management of large, intricate datasets by enabling the system to independently determine the optimal number of HMM states for various signs and integrating transition models to address the beginning and end of signs in continuous sign language.
#
# HMMs have significantly enhanced SLR over the past decade by incorporating signer independence, sensor fusion, and inherent model selection. In the future, the survey emphasizes a substantial correlation between HMMs and Recurrent Neural Networks (RNNs), indicating that both are essential for the modeling of sequences of random observations. The utilization of modern hardware platforms that include smartphone sensors (gyroscopes, LiDAR) in conjunction with cloud computing and frameworks such as MediaPipe is emphasized in future research directions to create more accessible, real-time sign language translation systems.

# %% [markdown]
# ## Google MediaPipe
#
# Google's MediaPipe is a cross-platform, open-source framework that is optimized for the development of real-time machine learning pipelines that process live video and audio streams. It enables developers to integrate modular, pre-built ML components—known as "Calculators"—into a processing graph at its core. Its primary strength is its capacity to manage complex, continuous data streams with an exceedingly low latency by aggressively optimizing hardware usage. As a result of the framework's unification, it is feasible to construct a single perception pipeline and deploy it seamlessly across a variety of ecosystems, such as the web, desktop, iOS, and Android.
#
# ### Android and Data Collection Synergy
#
# I employ MediaPipe as the primary framework for downstream processing after creating a custom Android application for data collection. MediaPipe achieves an exceptional level of performance on mobile devices by dynamically distributing computational duties between the CPU and GPU, utilizing on-device hardware acceleration. My application extracts raw spatial coordinates in real-time directly from the live camera stream by integrating the MediaPipe Android SDK. The application process frames locally, as opposed to archiving large, raw video files, which introduce parsing complexities and computational bottlenecks during training. It generates normalized, lightweight feature vectors, including digital joint angles, which significantly reduce storage requirements and provide a clean, highly structured dataset for the training of my sign language recognition models.
#
# ### Expanding Accessibility: The Web Application Transition
#
# The project's extension to a web-based platform is a highly viable and seamless progression following the deployment of the Android application. MediaPipe's comprehensive support for JavaScript and WebAssembly (Wasm) significantly simplifies this cross-platform transition. This architecture enables the direct execution of the same machine learning monitoring models that are used in the mobile environment with a standard web browser and a conventional webcam. As a result, developers can distribute web applications that are highly interactive and accessible without necessitating that end users install localized software. Additionally, the framework eliminates server-side computational costs and ensures strict user privacy by processing the live video feed locally and ensuring that it never leaves the user's device. This is due to the fact that inference is performed exclusively client-side.
#
# ### The Holistic Model's Effectiveness
#
# MediaPipe's Holistic Model provides an essential advantage in managing the multimodal complexity that is inherent in Sign Language Recognition. Sign language is not exclusively expressed through manual gestures; rather, it is a multifaceted, full-body grammar that is heavily reliant on arm kinematics, head orientation, and subtle facial expressions. The Holistic pipeline seamlessly integrates three distinct, synchronized monitoring models to address this multidimensionality. It simultaneously extracts 33 macroscopic pose landmarks, 21 precise articular nodes per hand, and up to 478 dynamic facial landmarks during execution. The recognition system is able to interpret the complete semantic context of a sign by capturing this dense, unified data stream, thereby surpassing the severe limitations of strictly hand-centric tracking models.

# %% [markdown]
# ## Dataset

# %% [markdown]
# At first, I intended to employ the Google ASL Fingerspelling dataset; however, its immense scale and emphasis on rapid, continuous sequence decoding proved to be too computationally intensive and extensive for the immediate scope of this research. Therefore, I chose to employ the Google ASL Signs dataset, which I strategically filtered to a more focused subset of categories in order to train and evaluate the core models for this project in a more efficient manner.
#
# It is crucial to assess the three principal landmark-based datasets published by Google AI in order to contextualize the available resources and justify this selection:
#
# 1. **Google - ASL Fingerspelling**
# *([https://www.kaggle.com/competitions/asl-fingerpelling](https://www.kaggle.com/competitions/asl-fingerpelling))*
# This dataset is designed to address the intricate task of identifying continuous, real-time fingerspelled sequences, which encompasses the monitoring of letters, numerals, and symbols within fluent signing. Although it is extremely beneficial for the development of continuous translation models, the overwhelming volume of sequential temporal data renders it exceptionally large. Processing this volume of continuous landmark data during the project's initial training phases resulted in a superfluous computational bottleneck.
#
# 2. **Google - Isolated Sign Language Recognition (ASL Signs)**
# *([https://www.kaggle.com/competitions/asl-signs](https://www.kaggle.com/competitions/asl-signs))*
# The ASL Signs dataset, in contrast to the fingerspelling dataset, concentrates on the recognition of isolated signs, which involves the mapping of spatial-temporal landmarks to distinct, whole-word concepts. The data is highly conducive to subsetting due to its segmentation into individual signs. I was able to construct and refine the architecture of the recognition system without being overburdened by the complexities of continuous sentence boundary detection or an inordinate amount of data volume by isolating a specific, manageable vocabulary of categories from this dataset.
#
# 3. **FSBoard**
# *([https://www.kaggle.com/datasets/googleai/fsboard](https://www.kaggle.com/datasets/googleai/fsboard))*
# FSBoard is widely acknowledged as the most comprehensive and comprehensive dataset of the three, serving as a vast repository of diverse fingerspelling and sign language data. The gold standard for training robust, generalized models that are capable of managing real-world variability is represented by this. Nevertheless, its comprehensiveness is unparalleled; however, its full utilization necessitates substantial high-performance computing resources. The practical decision to prototype and validate the current system using a focused subset of the ASL Signs dataset before scaling up to more comprehensive data repositories is further justified by acknowledging its status as the most complete benchmark.

# %% [markdown]
# | Feature | **ASL Fingerspelling** | **ASL Signs** | **FSBoard** |
# | --- | --- | --- | --- |
# | **Data Type** | Fingerspelled phrases | Isolated signs | Continuous fingerspelling |
# | **Data Size** | ~3.3M characters | ~94k instances | ~3.3M characters (266 hrs) |
# | **Format** | Parquet | Parquet | TFRecord, Parquet, MP4 |
# | **Key Aspect** | Focuses on spelling URLs/Phone #s | Focuses on 250 vocabulary words | Includes raw RGB video files |

# %%
import pyarrow
import pyarrow.parquet as pq
try:
    import pandas.core.arrays.arrow.extension_types
except Exception:
    pass

import numpy as np
import pandas as pd
import json, os, gc
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPUs: {len(gpus)}")
else:
    print("CPU mode")

from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow.keras.backend as K

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow.keras.backend as K

print(f"TF {tf.__version__}")
# Out:
# GPUs: 1
# TF 2.20.0

# %%
# Install the artlib library
# !pip install artlib

# Note: If the library is hosted on GitHub by Nik Melton, you might need to use a command like this instead:
# !pip install git+https://github.com/nikmelton/artlib.git
# Out:
# Requirement already satisfied: artlib in /usr/local/lib/python3.12/dist-packages (0.1.8)
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.12/dist-packages (from artlib) (2.0.2)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from artlib) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from artlib) (1.6.1)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.12/dist-packages (from artlib) (3.10.0)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.12/dist-packages (from artlib) (0.60.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.3->artlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.57.0->artlib) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->artlib) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->artlib) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->artlib) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ============================================================
# CONFIGURATION
# ============================================================
BASE_PATH    = Path('/content/drive/MyDrive/DATA/asl-signs')
TRAIN_CSV    = BASE_PATH / 'train.csv'
LANDMARK_DIR = BASE_PATH / 'train_landmark_files'
SIGN_MAP     = BASE_PATH / 'sign_to_prediction_index_map.json'
CKPT_DIR     = BASE_PATH / 'checkpoints'
CKPT_DIR.mkdir(exist_ok=True);

NUM_CLASSES_TO_USE    = 20
MAX_SAMPLES_PER_CLASS = 100   # More data per class
MAX_SEQ_LEN           = 64
BATCH_SIZE            = 32
EPOCHS                = 80
LR                    = 1e-3
VAL_SPLIT             = 0.15

# Landmark config
N_HAND  = 21
N_POSE  = 33
N_RAW   = (N_HAND * 2 + N_POSE) * 2   # 225 raw coords

# Feature engineering adds velocity + acceleration + relative coords
# Final feature dim computed after engineering
print(f"Max seq len : {MAX_SEQ_LEN}")
print(f"Batch size  : {BATCH_SIZE}")
# Out:
# Max seq len : 64
# Batch size  : 32

# %%
# ============================================================
# SAFE PARQUET READER
# ============================================================
def safe_read_parquet(filepath):
    try:
        table = pq.read_table(str(filepath))
        return table.to_pandas()
    except Exception as e:
        return None


# ============================================================
# FEATURE EXTRACTION — RAW COORDS (hands + pose only, X,Y only)
# ============================================================
def extract_raw_coords(df):
    """
    Returns (T, N_RAW) float32 array with raw x,y for
    left_hand(21) + right_hand(21) + pose(33) landmarks.
    Frames are densely remapped from whatever range they use.
    N_RAW = (N_HAND * 2 + N_POSE) * 2 = 150 (since z is excluded)
    """
    if df is None or len(df) == 0:
        return None

    df = df.dropna(subset=['frame']).copy()
    if len(df) == 0:
        return None

    unique_frames = np.sort(df['frame'].unique())
    n_frames = len(unique_frames)
    if n_frames < 4:
        return None

    frame_map = {int(f): i for i, f in enumerate(unique_frames)}
    df['fi'] = df['frame'].map(frame_map).astype(int)
    df['x']  = pd.to_numeric(df['x'], errors='coerce').fillna(0.0).astype(np.float32)
    df['y']  = pd.to_numeric(df['y'], errors='coerce').fillna(0.0).astype(np.float32)
    # Z-coordinates are explicitly excluded
    # df['z']  = pd.to_numeric(df['z'], errors='coerce').fillna(0.0).astype(np.float32)

    # N_RAW is now 150 (75 landmarks * 2 dimensions)
    raw = np.zeros((n_frames, N_RAW), dtype=np.float32)

    # Number of dimensions per landmark (x, y)
    NEW_DIM_PER_LANDMARK = 2

    def fill(mask, offset, max_lm):
        sub = df.loc[mask & (df['landmark_index'] < max_lm)]
        if len(sub) == 0:
            return
        fi = sub['fi'].values.astype(int)
        li = sub['landmark_index'].values.astype(int)
        # Adjust column calculation for only 2 dimensions (x, y)
        bi = offset + li * NEW_DIM_PER_LANDMARK
        # Check bounds: N_RAW refers to total x,y features
        ok = (fi < n_frames) & (bi + 1 < N_RAW) # +1 for y coord
        raw[fi[ok], bi[ok]]     = sub['x'].values[ok]
        raw[fi[ok], bi[ok] + 1] = sub['y'].values[ok]
        # No 'z' coordinate to fill

    # Adjust offsets based on 2 dimensions per landmark
    fill(df['type'] == 'left_hand',  0,                                  N_HAND)
    fill(df['type'] == 'right_hand', N_HAND * NEW_DIM_PER_LANDMARK,      N_HAND)
    fill(df['type'] == 'pose',       2 * N_HAND * NEW_DIM_PER_LANDMARK,  N_POSE)

    # Must have at least some hand signal (adjusted for 2 dimensions)
    hand_region = raw[:, :N_HAND * 2 * NEW_DIM_PER_LANDMARK]
    if np.count_nonzero(hand_region.sum(axis=1)) < 3:
        return None

    return raw   # (T, 150)

# %%
# ============================================================
# FEATURE ENGINEERING — the critical fix
# ============================================================
def engineer_features(raw):
    """
    Transform raw (T, N_RAW_2D) coords into meaningful features:

    1. RELATIVE coords: subtract wrist position so features are
       translation-invariant (person can sit anywhere)
    2. NORMALISED scale: divide by hand span so size-invariant
    3. VELOCITY: frame-to-frame differences (motion matters!)
    4. ACCELERATION: second-order differences
    5. Select only most informative landmarks

    Output: (T, feat_dim) — much more discriminative
    """
    T = raw.shape[0]

    # --- Z-coordinates are now already filtered by extract_raw_coords ---
    # raw is expected to be (T, (N_HAND*2 + N_POSE)*2) = (T, 150)
    NEW_DIM_PER_LANDMARK = 2 # only x, y

    # Direct assignment, as raw already contains only X,Y coordinates
    raw_2d_flat  = raw

    # ── Indices (adjusted for 2D) ──────────────────────────────
    # Left hand: landmarks 0..20 → cols 0.. (N_HAND * 2 - 1)
    # Right hand: landmarks 0..20 → cols (N_HAND * 2) .. (N_HAND * 4 - 1)
    # Pose: landmarks 0..32 → cols (N_HAND * 4) .. (N_ALL_LANDMARKS * 2 - 1)

    LH_START = 0
    RH_START = N_HAND * NEW_DIM_PER_LANDMARK
    PS_START = 2 * N_HAND * NEW_DIM_PER_LANDMARK

    # Wrist = landmark 0 of each hand (now only x, y)
    lh_wrist_x = raw_2d_flat[:, LH_START + 0]
    lh_wrist_y = raw_2d_flat[:, LH_START + 1]
    rh_wrist_x = raw_2d_flat[:, RH_START + 0]
    rh_wrist_y = raw_2d_flat[:, RH_START + 1]

    # ── 1. Relative hand coords (subtract wrist) ─────────────
    lh_rel = raw_2d_flat[:, LH_START:LH_START + N_HAND * NEW_DIM_PER_LANDMARK].copy()
    rh_rel = raw_2d_flat[:, RH_START:RH_START + N_HAND * NEW_DIM_PER_LANDMARK].copy()

    for i in range(N_HAND):
        lh_rel[:, i*NEW_DIM_PER_LANDMARK]   -= lh_wrist_x
        lh_rel[:, i*NEW_DIM_PER_LANDMARK+1] -= lh_wrist_y
        rh_rel[:, i*NEW_DIM_PER_LANDMARK]   -= rh_wrist_x
        rh_rel[:, i*NEW_DIM_PER_LANDMARK+1] -= rh_wrist_y

    # ── 2. Scale normalisation (by distance middle finger tip to wrist, now 2D) ──
    # LH middle finger tip = landmark 12
    lh_tip = np.sqrt(
        lh_rel[:, 12*NEW_DIM_PER_LANDMARK]**2 + lh_rel[:, 12*NEW_DIM_PER_LANDMARK+1]**2
    ).clip(min=1e-6)
    rh_tip = np.sqrt(
        rh_rel[:, 12*NEW_DIM_PER_LANDMARK]**2 + rh_rel[:, 12*NEW_DIM_PER_LANDMARK+1]**2
    ).clip(min=1e-6)

    lh_rel /= lh_tip[:, None]
    rh_rel /= rh_tip[:, None]

    # ── 3. Pose: use only upper body (landmarks 0-16 = head+shoulders+arms, now 2D) ──
    # N_ALL_LANDMARKS is 75 (21+21+33). 17 landmarks from pose are selected
    N_ALL_LANDMARKS = N_HAND * 2 + N_POSE
    pose_sel_start_idx = 2 * N_HAND * NEW_DIM_PER_LANDMARK # Start of pose in raw_2d_flat
    pose_sel = raw_2d_flat[:, pose_sel_start_idx : pose_sel_start_idx + 17*NEW_DIM_PER_LANDMARK]  # 17 landmarks * 2 = 34

    # Relative to nose (landmark 0 of pose)
    nose_x = pose_sel[:, 0]
    nose_y = pose_sel[:, 1]
    for i in range(17):
        pose_sel[:, i*NEW_DIM_PER_LANDMARK]   -= nose_x
        pose_sel[:, i*NEW_DIM_PER_LANDMARK+1] -= nose_y

    # ── 4. Concatenate spatial features (adjusted for 2D) ─────────────────────
    # lh_rel: (21*2) = 42, rh_rel: (21*2) = 42, pose_sel: (17*2) = 34 → 42+42+34 = 118
    spatial = np.concatenate([lh_rel, rh_rel, pose_sel], axis=1)  # (T, 118)

    # ── 5. Velocity (frame differences) ─────────────────────
    # Pad first row so shape stays (T, 118)
    velocity = np.zeros_like(spatial)
    velocity[1:] = spatial[1:] - spatial[:-1]

    # ── 6. Acceleration ──────────────────────────────────────
    accel = np.zeros_like(spatial)
    accel[2:] = velocity[2:] - velocity[1:-1]

    # ── 7. Absolute wrist positions (where hands are in frame, now 2D) ──
    wrist_pos = np.stack([
        lh_wrist_x, lh_wrist_y,
        rh_wrist_x, rh_wrist_y
    ], axis=1)   # (T, 4)

    # Velocity of wrist
    wrist_vel = np.zeros_like(wrist_pos)
    wrist_vel[1:] = wrist_pos[1:] - wrist_pos[:-1]

    # ── 8. Combine all (adjusted for 2D) ───────────────────────────
    # spatial:118 + velocity:118 + accel:118 + wrist:4 + wrist_vel:4 = 354 + 8 = 362
    features = np.concatenate([
        spatial,      # shape (T, 118)
        velocity,     # shape (T, 118)
        accel,        # shape (T, 118)
        wrist_pos,    # shape (T, 4)
        wrist_vel     # shape (T, 4)
    ], axis=1)        # → (T, 362)

    return features.astype(np.float32)


def resample_seq(seq, target_len):
    """
    Temporally resample to fixed length.
    """
    T = seq.shape[0]
    if T == target_len:
        return seq
    idx = np.round(np.linspace(0, T - 1, target_len)).astype(int)
    return seq[idx]


def per_sequence_normalize(seq):
    """
    Normalize each sequence independently.
    This is critical — global normalization loses relative info.
    Use robust normalization: subtract median, divide by IQR.
    """
    # Only normalize non-zero features
    flat = seq.reshape(-1)
    nonzero = flat[flat != 0]
    if len(nonzero) == 0:
        return seq
    median = np.median(nonzero)
    q75, q25 = np.percentile(nonzero, [75, 25])
    iqr = q75 - q25
    if iqr < 1e-8:
        iqr = nonzero.std() + 1e-8
    return ((seq - median) / iqr).clip(-10, 10).astype(np.float32)

# %%
# ============================================================
# DATA AUGMENTATION
# ============================================================
def augment_sequence(seq, training=True):
    """
    Apply random augmentations to prevent overfitting.
    seq: (T, F)
    """
    if not training:
        return seq

    # 1. Time warping: random speed up/slow down
    if np.random.random() < 0.5:
        T = seq.shape[0]
        # Random stretch factor 0.8–1.2
        factor = np.random.uniform(0.8, 1.2)
        new_T  = int(T * factor)
        new_T  = max(4, new_T)
        idx    = np.round(np.linspace(0, T-1, new_T)).astype(int)
        seq    = resample_seq(seq[idx], T)

    # 2. Gaussian noise
    if np.random.random() < 0.5:
        noise = np.random.normal(0, 0.02, seq.shape).astype(np.float32)
        seq   = seq + noise

    # 3. Random frame dropout (simulate missing frames)
    if np.random.random() < 0.3:
        T       = seq.shape[0]
        n_drop  = np.random.randint(1, max(2, T // 8))
        drop_idx = np.random.choice(T, n_drop, replace=False)
        seq     = seq.copy()
        seq[drop_idx] = 0.0

    # 4. Horizontal flip (mirror signing)
    if np.random.random() < 0.5:
        # Since Z-axis was removed, we only have (x,y) pairs.
        # We need to selectively flip only the 'x' coordinates.

        # These are global constants from the config/feature engineering cells
        N_HAND = 21
        NEW_DIM_PER_LANDMARK = 2 # x, y
        # The spatial block size as computed in engineer_features
        FEAT_DIM_SPATIAL = (N_HAND * NEW_DIM_PER_LANDMARK) + \
                           (N_HAND * NEW_DIM_PER_LANDMARK) + \
                           (17 * NEW_DIM_PER_LANDMARK)

        # Collect indices of all x-coordinates in the feature vector
        spatial_x_indices = []

        # --- Spatial features (lh_rel, rh_rel, pose_sel) ---
        # lh_rel (N_HAND landmarks * 2 dimensions = 42 features) - x at 0, 2, ..., 40
        spatial_x_indices.extend(range(0, N_HAND * NEW_DIM_PER_LANDMARK, NEW_DIM_PER_LANDMARK))
        # rh_rel (N_HAND landmarks * 2 dimensions = 42 features) - x at 42, 44, ..., 82
        spatial_x_indices.extend(range(N_HAND * NEW_DIM_PER_LANDMARK, 2 * N_HAND * NEW_DIM_PER_LANDMARK, NEW_DIM_PER_LANDMARK))
        # pose_sel (17 landmarks * 2 dimensions = 34 features) - x at 84, 86, ..., 116
        spatial_x_indices.extend(range(2 * N_HAND * NEW_DIM_PER_LANDMARK, FEAT_DIM_SPATIAL, NEW_DIM_PER_LANDMARK))

        x_indices = list(spatial_x_indices)

        # --- Velocity features (shifted by FEAT_DIM_SPATIAL) ---
        x_indices.extend([idx + FEAT_DIM_SPATIAL for idx in spatial_x_indices])

        # --- Acceleration features (shifted by 2 * FEAT_DIM_SPATIAL) ---
        x_indices.extend([idx + 2 * FEAT_DIM_SPATIAL for idx in spatial_x_indices])

        # --- Absolute wrist positions (lh_x, rh_x) ---
        # These are at FEAT_DIM_SPATIAL*3 + 0 and FEAT_DIM_SPATIAL*3 + 2
        wrist_pos_start = 3 * FEAT_DIM_SPATIAL
        x_indices.extend([wrist_pos_start + 0, wrist_pos_start + 2])

        # --- Absolute wrist velocities (lh_vx, rh_vx) ---
        # These are at FEAT_DIM_SPATIAL*3 + 4 + 0 and FEAT_DIM_SPATIAL*3 + 4 + 2
        wrist_vel_start = 3 * FEAT_DIM_SPATIAL + 4 # 4 comes from 2x y and 2x x
        x_indices.extend([wrist_vel_start + 0, wrist_vel_start + 2])

        # Negate only the identified x-coordinates
        seq = seq.copy()
        seq[:, x_indices] *= -1.0

    return seq.astype(np.float32)

# %%
# ============================================================
# tf.data PIPELINE WITH AUGMENTATION
# ============================================================
def make_dataset(X, y, training=False, batch_size=32):
    """
    Build a tf.data.Dataset with optional augmentation.
    """
    if training:
        @tf.function
        def aug_fn(x, label):
            x = tf.numpy_function(
                lambda s: augment_sequence(s.numpy() if hasattr(s,'numpy') else s,
                                           training=True),
                [x], tf.float32
            )
            x.set_shape([MAX_SEQ_LEN, FEAT_DIM])
            return x, label

        ds = (tf.data.Dataset.from_tensor_slices((X, y))
              .shuffle(len(X), seed=42)
              .map(aug_fn, num_parallel_calls=tf.data.AUTOTUNE)
              .batch(batch_size)
              .prefetch(tf.data.AUTOTUNE))
    else:
        ds = (tf.data.Dataset.from_tensor_slices((X, y))
              .batch(batch_size)
              .prefetch(tf.data.AUTOTUNE))
    return ds

# %%
# ============================================================
# [1/7] LOAD METADATA
# ============================================================
print("\n[1/7] Loading metadata...")
train_df = pd.read_csv(TRAIN_CSV)
with open(SIGN_MAP) as f:
    sign_to_idx = json.load(f)

print(f"  CSV rows     : {len(train_df)}")
print(f"  Unique signs : {train_df['sign'].nunique()}")
# Out:
# [1/7] Loading metadata...
#   CSV rows     : 94477
#   Unique signs : 250

# %%
# ============================================================
# [2/7] SAMPLE BALANCED SUBSET
# ============================================================
print("\n[2/7] Sampling...")
np.random.seed(42)

all_signs      = train_df['sign'].unique()
selected_signs = np.random.choice(
    all_signs,
    size=min(NUM_CLASSES_TO_USE, len(all_signs)),
    replace=False
)

rows = [train_df[train_df['sign'] == s].head(MAX_SAMPLES_PER_CLASS)
        for s in selected_signs]
sampled_df = (pd.concat(rows, ignore_index=True)
                .sample(frac=1, random_state=42)
                .reset_index(drop=True))

print(f"  Sequences : {len(sampled_df)}")
print(f"  Classes   : {sampled_df['sign'].nunique()}")
# Out:
# [2/7] Sampling...
#   Sequences : 2000
#   Classes   : 20

# %%
# ============================================================
# [3/7] LOAD + ENGINEER FEATURES
# ============================================================
print("\n[3/7] Loading and engineering features...")

X_list, y_list = [], []
n_ok = n_miss = n_bad = 0

for i, (_, row) in enumerate(sampled_df.iterrows()):
    if (i % 200) == 0:
        #print(i)
        print(str(i) + ' out of ' + str(len(sampled_df)))
        print(f"  [{i:>5}/{len(sampled_df)}] ok={n_ok} bad={n_bad}")

    fp = (LANDMARK_DIR / str(row['participant_id'])
          / f"{row['sequence_id']}.parquet")

    if not fp.exists():
        n_miss += 1
        continue

    df_raw = safe_read_parquet(fp)
    if df_raw is None:
        n_bad += 1
        continue

    # Extract raw coordinates
    raw = extract_raw_coords(df_raw)
    del df_raw

    if raw is None:
        n_bad += 1
        continue

    # Engineer features (velocity, relative coords, etc.)
    feat = engineer_features(raw)
    del raw

    # Resample to fixed length
    feat = resample_seq(feat, MAX_SEQ_LEN)

    # Per-sequence normalization
    feat = per_sequence_normalize(feat)

    X_list.append(feat)
    y_list.append(row['sign'])
    n_ok += 1
    del feat

    if i % 500 == 0:
        gc.collect()

print(f"\n  Loaded  : {n_ok}")
print(f"  Missing : {n_miss}")
print(f"  Bad     : {n_bad}")

if n_ok == 0:
    raise SystemExit("0 sequences loaded!")

# Compute FEAT_DIM from actual data
FEAT_DIM = X_list[0].shape[1]
print(f"  Feature dim (engineered): {FEAT_DIM}")
# Out:
# [3/7] Loading and engineering features...
# 0 out of 2000
#   [    0/2000] ok=0 bad=0
# 200 out of 2000
#   [  200/2000] ok=191 bad=9
# 400 out of 2000
#   [  400/2000] ok=369 bad=31
# 600 out of 2000
#   [  600/2000] ok=563 bad=37
# 800 out of 2000
#   [  800/2000] ok=749 bad=51
# 1000 out of 2000
#   [ 1000/2000] ok=934 bad=66
# 1200 out of 2000
#   [ 1200/2000] ok=1126 bad=74
# 1400 out of 2000
#   [ 1400/2000] ok=1310 bad=90
# 1600 out of 2000
#   [ 1600/2000] ok=1491 bad=109
# 1800 out of 2000
#   [ 1800/2000] ok=1678 bad=122
#
#   Loaded  : 1865
#   Missing : 0
#   Bad     : 135
#   Feature dim (engineered): 362

# %%
# ============================================================
# [4/7] BUILD ARRAYS
# ============================================================
print("\n[4/7] Building arrays...")

X = np.array(X_list, dtype=np.float32)
del X_list; gc.collect()

print(f"  X shape : {X.shape}")
print(f"  X range : [{X.min():.3f}, {X.max():.3f}]")
print(f"  X mean  : {X.mean():.4f}  std: {X.std():.4f}")

# Encode labels
le    = LabelEncoder()
y_int = le.fit_transform(y_list)
n_cls = len(le.classes_)
y_cat = keras.utils.to_categorical(y_int, n_cls)

print(f"  Classes : {n_cls}")

# Save for inference
np.save(CKPT_DIR / 'label_classes.npy', le.classes_)
with open(CKPT_DIR / 'config.json', 'w') as f:
    json.dump({'feat_dim': FEAT_DIM, 'max_seq_len': MAX_SEQ_LEN,
               'n_classes': n_cls}, f)

# Split
X_tr, X_vl, y_tr, y_vl, yint_tr, yint_vl = train_test_split(
    X, y_cat, y_int,
    test_size=VAL_SPLIT, random_state=42, stratify=y_int
)
print(f"  Train : {X_tr.shape}   Val : {X_vl.shape}")
del X, y_cat; gc.collect()
# Out:
# [4/7] Building arrays...
#   X shape : (1865, 64, 362)
#   X range : [-10.000, 10.000]
#   X mean  : 0.1199  std: 1.9015
#   Classes : 20
#   Train : (1585, 64, 362)   Val : (280, 64, 362)
# 32

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# ============================================================
# [5/7] VISUALIZATIONS
# ============================================================
print("\n[5/7] Plots...")

fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Class distribution
pd.Series(y_list).value_counts().hist(bins=20, ax=axes[0,0],
                                       edgecolor='black', color='steelblue')
axes[0,0].set_xlabel('Samples/class'); axes[0,0].set_ylabel('Count')
axes[0,0].set_title('Class Distribution')

# Sample sequence heatmap
axes[0,1].imshow(X_tr[0].T, aspect='auto', cmap='RdBu_r', vmin=-3, vmax=3)
axes[0,1].set_xlabel('Frame'); axes[0,1].set_ylabel('Feature')
axes[0,1].set_title(f'Engineered Features: {y_list[0]}')

# Velocity features (first 42 = velocity of left hand)
vel_start = 118  # Start of LH velocity block
axes[0,2].imshow(X_tr[0, :, vel_start:vel_start+42].T,
                 aspect='auto', cmap='RdBu_r', vmin=-3, vmax=3)
axes[0,2].set_xlabel('Frame'); axes[0,2].set_ylabel('Feature')
axes[0,2].set_title('Velocity Features (Left Hand)')

# Feature energy breakdown
blocks = {
    'LH spatial': (0, 42),
    'RH spatial': (42, 84),
    'Pose spatial': (84, 118),
    'LH velocity': (118, 160),
    'RH velocity': (160, 202),
    'Pose velocity': (202, 236),
    'LH accel': (236, 278),
    'RH accel': (278, 320),
    'Pose accel': (320, 354),
    'Wrist pos': (354, 358),
    'Wrist vel': (358, 362),
}
energies = {k: np.abs(X_tr[:, :, s:e]).mean() for k, (s,e) in blocks.items()}
axes[1,0].barh(list(energies.keys()), list(energies.values()), alpha=0.8)
axes[1,0].set_xlabel('Mean |value|')
axes[1,0].set_title('Feature Block Energy')
axes[1,0].grid(True, alpha=0.3, axis='x')

# Per-class sample count
class_counts = pd.Series(y_list).value_counts()
axes[1,1].bar(range(len(class_counts)), sorted(class_counts.values, reverse=True),
              alpha=0.75, width=1.0)
axes[1,1].set_xlabel('Class (sorted)'); axes[1,1].set_ylabel('Count')
axes[1,1].set_title('Samples per Class')
axes[1,1].axhline(class_counts.mean(), color='red', ls='--',
                   label=f'Mean {class_counts.mean():.0f}')
axes[1,1].legend()

# Sequence length distribution (original before resampling)
axes[1,2].text(0.5, 0.5,
               f'Feature Dim: {FEAT_DIM}\n'
               f'Seq Length: {MAX_SEQ_LEN}\n'
               f'Train samples: {len(X_tr)}\n'
               f'Val samples: {len(X_vl)}\n'
               f'Classes: {n_cls}\n'
               f'Samples/class: ~{len(X_tr)//n_cls}',
               transform=axes[1,2].transAxes,
               ha='center', va='center', fontsize=13,
               bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
axes[1,2].set_title('Dataset Info')
axes[1,2].axis('off')

plt.tight_layout()
plt.savefig(CKPT_DIR / 'data_overview.png', dpi=120)
plt.show()
# plt.close() # Removed to display the plot
print("  Saved data_overview.png")
# Out:
# [5/7] Plots...
#   Saved data_overview.png

# %%
# ============================================================
# MODEL BUILDERS — improved architectures
# ============================================================
INPUT_SHAPE = (MAX_SEQ_LEN, FEAT_DIM)

def build_conv_lstm_v2(n_cls, feat_dim, seq_len):
    """
    Improved Conv1D-LSTM with:
    - Residual connections
    - Layer normalization
    - Larger capacity
    - Separate processing of spatial/velocity/accel streams
    """
    inp = layers.Input(shape=(seq_len, feat_dim))

    # ── Multi-scale temporal convolutions ──────────────────
    def conv_block(x, filters, kernel, dilation=1):
        y = layers.Conv1D(filters, kernel, padding='causal',
                          dilation_rate=dilation, use_bias=False)(x)
        y = layers.LayerNormalization()(y)
        y = layers.Activation('relu')(y)
        return y

    # Three parallel streams at different temporal scales
    s1 = conv_block(inp, 128, 3, dilation=1)   # fine-grained
    s2 = conv_block(inp, 128, 3, dilation=2)   # medium
    s3 = conv_block(inp, 128, 3, dilation=4)   # coarse

    x = layers.Concatenate()([s1, s2, s3])   # (T, 384)
    x = layers.Conv1D(256, 1, activation='relu')(x)   # project down

    # ── Residual LSTM blocks ────────────────────────────────
    def lstm_residual(x, units):
        shortcut = layers.Conv1D(units*2, 1)(x)  # match dim for residual
        y = layers.Bidirectional(
                layers.LSTM(units, return_sequences=True, dropout=0.1))(x)
        y = layers.LayerNormalization()(y)
        return layers.Add()([y, shortcut])

    x = lstm_residual(x, 128)   # → (T, 256)
    x = layers.Dropout(0.3)(x)
    x = lstm_residual(x, 64)    # → (T, 128)
    x = layers.Dropout(0.3)(x)

    # ── Attention pooling ───────────────────────────────────
    # Learn which frames are most important
    attn = layers.Dense(1, activation='tanh')(x)        # (T, 1)
    attn = layers.Softmax(axis=1)(attn)                 # (T, 1)
    x    = layers.Multiply()([x, attn])                 # weighted frames
    x    = layers.GlobalAveragePooling1D()(x)           # (128,)

    # ── Classifier ─────────────────────────────────────────
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(n_cls, activation='softmax')(x)

    return Model(inp, out, name='ConvLSTM_v2')


def build_transformer(n_cls, feat_dim, seq_len):
    """
    Transformer encoder — excellent for sequence classification.
    """
    inp = layers.Input(shape=(seq_len, feat_dim))

    # Project to embedding dim
    embed_dim = 128
    x = layers.Dense(embed_dim)(inp)
    x = layers.LayerNormalization()(x)

    # Positional encoding
    positions  = tf.range(start=0, limit=seq_len, delta=1)
    pos_embed  = layers.Embedding(seq_len, embed_dim)(positions)
    x = x + pos_embed

    # Transformer encoder blocks
    for _ in range(4):
        # Multi-head self-attention
        attn_out = layers.MultiHeadAttention(
            num_heads=4, key_dim=32, dropout=0.1)(x, x)
        x = layers.LayerNormalization()(x + attn_out)

        # Feed-forward
        ff = layers.Dense(embed_dim * 4, activation='relu')(x)
        ff = layers.Dropout(0.1)(ff)
        ff = layers.Dense(embed_dim)(ff)
        x  = layers.LayerNormalization()(x + ff)

    # Global average pool over sequence
    x   = layers.GlobalAveragePooling1D()(x)
    x   = layers.Dense(256, activation='relu')(x)
    x   = layers.Dropout(0.4)(x)
    x   = layers.Dense(128, activation='relu')(x)
    x   = layers.Dropout(0.3)(x)
    out = layers.Dense(n_cls, activation='softmax')(x)

    return Model(inp, out, name='Transformer')


def build_modern_rnn(n_cls, feat_dim, seq_len):
    """
    Modern RNN utilizing Bidirectional GRUs and Layer Normalization.
    Replaces the underperforming TCN.
    """
    inp = layers.Input(shape=(seq_len, feat_dim))

    # Projection
    x = layers.Dense(128, activation='gelu')(inp)
    x = layers.LayerNormalization()(x)

    # Multi-layer BiGRU
    x = layers.Bidirectional(layers.GRU(128, return_sequences=True, dropout=0.2))(x)
    x = layers.LayerNormalization()(x)
    x = layers.Bidirectional(layers.GRU(128, return_sequences=False, dropout=0.2))(x)

    # Classifier
    x = layers.Dense(256, activation='gelu')(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='gelu')(x)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(n_cls, activation='softmax')(x)

    return Model(inp, out, name='Modern_RNN')


def build_hybrid_model(n_cls, feat_dim, seq_len):
    """
    Hybrid CNN-Transformer inspired by the Kaggle 2nd place solution.
    Uses 1D Conv layers to capture local, high-resolution temporal features
    and downsample the sequence, then a Transformer for global semantic context.
    """
    inp = layers.Input(shape=(seq_len, feat_dim))

    # Local Context & Multi-Resolution Downsampling (CNN)
    x = layers.Conv1D(128, 5, padding='same', activation='gelu')(inp)
    x = layers.MaxPooling1D(pool_size=2)(x)  # Halves the temporal resolution
    x = layers.Conv1D(256, 3, padding='same', activation='gelu')(x)
    x = layers.LayerNormalization()(x)

    # Prepare for Transformer (Global Context)
    new_seq_len = seq_len // 2
    embed_dim = 256

    positions = tf.range(start=0, limit=new_seq_len, delta=1)
    pos_embed = layers.Embedding(new_seq_len, embed_dim)(positions)
    x = x + pos_embed

    # Conformer/Transformer Blocks
    for _ in range(3):
        attn_out = layers.MultiHeadAttention(num_heads=4, key_dim=64, dropout=0.1)(x, x)
        x = layers.LayerNormalization()(x + attn_out)

        ff = layers.Dense(embed_dim * 2, activation='gelu')(x)
        ff = layers.Dropout(0.1)(ff)
        ff = layers.Dense(embed_dim)(ff)
        x = layers.LayerNormalization()(x + ff)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(256, activation='gelu')(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='gelu')(x)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(n_cls, activation='softmax')(x)

    return Model(inp, out, name='Hybrid_CNN_Transformer')


def build_deep_artmap(n_cls, feat_dim, seq_len):
    """
    Adaptive Resonance Theory (Shallow Neural Network)
    Placeholder for DeepARTMAP integration.
    Requires AdaptiveResonanceLib: https://github.com/NiklasMelton/AdaptiveResonanceLib
    """
    # Example implementation structure using a Keras wrapper if supported
    # or simply defining a custom layer/model. Here we provide a dense proxy.
    inp = layers.Input(shape=(seq_len, feat_dim))
    x = layers.Flatten()(inp)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dense(256, activation='relu')(x)
    out = layers.Dense(n_cls, activation='softmax')(x)
    return Model(inp, out, name='DeepARTMAP_Proxy')

# ============================================================
# TRAINING HELPER
# ============================================================
def cosine_decay_with_warmup(epoch, total_epochs=80, warmup_epochs=5, base_lr=1e-3):
    if epoch < warmup_epochs:
        return base_lr * (epoch + 1) / warmup_epochs
    progress = (epoch - warmup_epochs) / (total_epochs - warmup_epochs)
    return base_lr * 0.5 * (1 + np.cos(np.pi * progress))


def train_one(model, tag, X_tr, y_tr, X_vl, y_vl):
    model.compile(
        optimizer=keras.optimizers.Adam(LR, clipnorm=1.0),
        loss='categorical_crossentropy',
        metrics=['accuracy',
                 keras.metrics.TopKCategoricalAccuracy(k=5, name='top5')]
    )
    model.summary()

    # Build datasets with augmentation
    train_ds = make_dataset(X_tr, y_tr, training=True,  batch_size=BATCH_SIZE)
    val_ds   = make_dataset(X_vl, y_vl, training=False, batch_size=BATCH_SIZE)

    lr_scheduler = keras.callbacks.LearningRateScheduler(
        lambda epoch: cosine_decay_with_warmup(epoch, EPOCHS, 5, LR),
        verbose=0
    )

    h = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=[
            ModelCheckpoint(str(CKPT_DIR / f'{tag}_best.keras'),
                            monitor='val_accuracy', save_best_only=True, verbose=0),
            EarlyStopping(monitor='val_loss', patience=15,
                          restore_best_weights=True, verbose=1),
            lr_scheduler,
        ],
        verbose=1
    )

    _, acc, top5 = model.evaluate(val_ds, verbose=0)
    print(f"  {tag} → acc={acc:.4f}  top5={top5:.4f}")
    return h, float(acc), float(top5)


def plot_hist(h, tag):
    fig, axes = plt.subplots(1, 3, figsize=(16, 4))
    for ax, k, t in zip(axes,
                         ['accuracy', 'loss', 'top5'],
                         ['Accuracy', 'Loss', 'Top-5']):
        if k in h.history:
            ax.plot(h.history[k], label='Train')
        if f'val_{k}' in h.history:
            ax.plot(h.history[f'val_{k}'], label='Val')
        ax.set_title(f'{tag} – {t}')
        ax.set_xlabel('Epoch'); ax.legend(); ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(CKPT_DIR / f'{tag}_history.png', dpi=120)
    plt.close()


# ============================================================
# [6/7] TRAIN 5 MODELS
# ============================================================
print("\n[6/7] Training...")

# ── Model 1: Conv-LSTM with attention ──
print("\n━━━ Conv-LSTM v2 (with attention) ━━━")
K.clear_session(); gc.collect()
m1 = build_conv_lstm_v2(n_cls, FEAT_DIM, MAX_SEQ_LEN)
h1, a1, t1 = train_one(m1, 'conv_lstm_v2', X_tr, y_tr, X_vl, y_vl)
val_ds_plain = make_dataset(X_vl, y_vl, training=False, batch_size=BATCH_SIZE)
p1 = m1.predict(val_ds_plain, verbose=0)
plot_hist(h1, 'ConvLSTM_v2')
del m1; K.clear_session(); gc.collect()

# ── Model 2: Transformer ──
print("\n━━━ Transformer ━━━")
K.clear_session(); gc.collect()
m2 = build_transformer(n_cls, FEAT_DIM, MAX_SEQ_LEN)
h2, a2, t2 = train_one(m2, 'transformer', X_tr, y_tr, X_vl, y_vl)
val_ds_plain = make_dataset(X_vl, y_vl, training=False, batch_size=BATCH_SIZE)
p2 = m2.predict(val_ds_plain, verbose=0)
plot_hist(h2, 'Transformer')
del m2; K.clear_session(); gc.collect()

# ── Model 3: Modern RNN ──
print("\n━━━ Modern RNN ━━━")
K.clear_session(); gc.collect()
m3 = build_modern_rnn(n_cls, FEAT_DIM, MAX_SEQ_LEN)
h3, a3, t3 = train_one(m3, 'modern_rnn', X_tr, y_tr, X_vl, y_vl)
val_ds_plain = make_dataset(X_vl, y_vl, training=False, batch_size=BATCH_SIZE)
p3 = m3.predict(val_ds_plain, verbose=0)
plot_hist(h3, 'Modern_RNN')
del m3; K.clear_session(); gc.collect()

# ── Model 4: Hybrid CNN-Transformer ──
print("\n━━━ Hybrid CNN-Transformer ━━━")
K.clear_session(); gc.collect()
m4 = build_hybrid_model(n_cls, FEAT_DIM, MAX_SEQ_LEN)
h4, a4, t4 = train_one(m4, 'hybrid_cnn_transformer', X_tr, y_tr, X_vl, y_vl)
val_ds_plain = make_dataset(X_vl, y_vl, training=False, batch_size=BATCH_SIZE)
p4 = m4.predict(val_ds_plain, verbose=0)
plot_hist(h4, 'Hybrid')
del m4; K.clear_session(); gc.collect()

# ── Model 5: DeepARTMAP Proxy ──
print("\n━━━ DeepARTMAP Proxy ━━━")
K.clear_session(); gc.collect()
m5 = build_deep_artmap(n_cls, FEAT_DIM, MAX_SEQ_LEN)
h5, a5, t5 = train_one(m5, 'deep_artmap_proxy', X_tr, y_tr, X_vl, y_vl)
val_ds_plain = make_dataset(X_vl, y_vl, training=False, batch_size=BATCH_SIZE)
p5 = m5.predict(val_ds_plain, verbose=0)
plot_hist(h5, 'DeepARTMAP_Proxy')
del m5; K.clear_session(); gc.collect()
# Out:
# [6/7] Training...
#
# ━━━ Conv-LSTM v2 (with attention) ━━━
# Model: "ConvLSTM_v2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 362)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 128)   │    139,008 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 64, 128)   │    139,008 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 64, 128)   │    139,008 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 64, 128)   │        256 │ conv1d[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ conv1d_1[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ conv1d_2[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 384)   │          0 │ activation[0][0], │
# │ (Concatenate)       │                   │            │ activation_1[0][… │
# │                     │                   │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 64, 256)   │     98,560 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 64, 256)   │    394,240 │ conv1d_3[0][0]    │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 256)   │        512 │ bidirectional[0]… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 64, 256)   │     65,792 │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 256)   │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64, 256)   │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 64, 128)   │    164,352 │ dropout[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ bidirectional_1[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 64, 128)   │     32,896 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 128)   │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64, 1)     │        129 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax (Softmax)   │ (None, 64, 1)     │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 64, 128)   │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ softmax[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ multiply[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │     32,896 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 20)        │      2,580 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,243,029 (4.74 MB)
#  Trainable params: 1,243,029 (4.74 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 65ms/step - accuracy: 0.0543 - loss: 2.9945 - top5: 0.2631 - val_accuracy: 0.0750 - val_loss: 2.9919 - val_top5: 0.3000 - learning_rate: 2.0000e-04
# Epoch 2/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.0549 - loss: 2.9903 - top5: 0.2845 - val_accuracy: 0.0893 - val_loss: 2.9709 - val_top5: 0.4321 - learning_rate: 4.0000e-04
# Epoch 3/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.0871 - loss: 2.9082 - top5: 0.3912 - val_accuracy: 0.1036 - val_loss: 2.8141 - val_top5: 0.4214 - learning_rate: 6.0000e-04
# Epoch 4/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.1054 - loss: 2.7649 - top5: 0.4700 - val_accuracy: 0.1357 - val_loss: 2.6265 - val_top5: 0.5679 - learning_rate: 8.0000e-04
# Epoch 5/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.1438 - loss: 2.6519 - top5: 0.5420 - val_accuracy: 0.1821 - val_loss: 2.5097 - val_top5: 0.5893 - learning_rate: 0.0010
# Epoch 6/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.1785 - loss: 2.5339 - top5: 0.6202 - val_accuracy: 0.2179 - val_loss: 2.3422 - val_top5: 0.7036 - learning_rate: 0.0010
# Epoch 7/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2145 - loss: 2.3998 - top5: 0.6852 - val_accuracy: 0.2607 - val_loss: 2.1830 - val_top5: 0.7500 - learning_rate: 9.9956e-04
# Epoch 8/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2423 - loss: 2.3041 - top5: 0.7161 - val_accuracy: 0.3429 - val_loss: 2.0989 - val_top5: 0.7643 - learning_rate: 9.9825e-04
# Epoch 9/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.3022 - loss: 2.1279 - top5: 0.7779 - val_accuracy: 0.4357 - val_loss: 1.9126 - val_top5: 0.8571 - learning_rate: 9.9606e-04
# Epoch 10/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.3180 - loss: 1.9935 - top5: 0.8120 - val_accuracy: 0.3964 - val_loss: 1.8104 - val_top5: 0.8714 - learning_rate: 9.9300e-04
# Epoch 11/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3489 - loss: 1.9176 - top5: 0.8284 - val_accuracy: 0.4536 - val_loss: 1.7147 - val_top5: 0.8750 - learning_rate: 9.8907e-04
# Epoch 12/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.3596 - loss: 1.8854 - top5: 0.8473 - val_accuracy: 0.4179 - val_loss: 1.7819 - val_top5: 0.8571 - learning_rate: 9.8429e-04
# Epoch 13/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.3905 - loss: 1.8240 - top5: 0.8549 - val_accuracy: 0.4429 - val_loss: 1.6794 - val_top5: 0.8607 - learning_rate: 9.7866e-04
# Epoch 14/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.3937 - loss: 1.7551 - top5: 0.8719 - val_accuracy: 0.4179 - val_loss: 1.6430 - val_top5: 0.8607 - learning_rate: 9.7219e-04
# Epoch 15/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4189 - loss: 1.7289 - top5: 0.8675 - val_accuracy: 0.4179 - val_loss: 1.6892 - val_top5: 0.8679 - learning_rate: 9.6489e-04
# Epoch 16/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.4467 - loss: 1.6090 - top5: 0.8965 - val_accuracy: 0.4964 - val_loss: 1.5412 - val_top5: 0.8821 - learning_rate: 9.5677e-04
# Epoch 17/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.4549 - loss: 1.6316 - top5: 0.8959 - val_accuracy: 0.4821 - val_loss: 1.5437 - val_top5: 0.9000 - learning_rate: 9.4786e-04
# Epoch 18/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4656 - loss: 1.5685 - top5: 0.9022 - val_accuracy: 0.4821 - val_loss: 1.5888 - val_top5: 0.8857 - learning_rate: 9.3815e-04
# Epoch 19/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4826 - loss: 1.5364 - top5: 0.9104 - val_accuracy: 0.5143 - val_loss: 1.4550 - val_top5: 0.8929 - learning_rate: 9.2768e-04
# Epoch 20/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5174 - loss: 1.4652 - top5: 0.9155 - val_accuracy: 0.4714 - val_loss: 1.5439 - val_top5: 0.8857 - learning_rate: 9.1646e-04
# Epoch 21/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5098 - loss: 1.4357 - top5: 0.9199 - val_accuracy: 0.5321 - val_loss: 1.4064 - val_top5: 0.8964 - learning_rate: 9.0451e-04
# Epoch 22/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5167 - loss: 1.4322 - top5: 0.9186 - val_accuracy: 0.5357 - val_loss: 1.4386 - val_top5: 0.9143 - learning_rate: 8.9185e-04
# Epoch 23/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5350 - loss: 1.3936 - top5: 0.9262 - val_accuracy: 0.5393 - val_loss: 1.4845 - val_top5: 0.9071 - learning_rate: 8.7850e-04
# Epoch 24/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5558 - loss: 1.3239 - top5: 0.9237 - val_accuracy: 0.5679 - val_loss: 1.3503 - val_top5: 0.9036 - learning_rate: 8.6448e-04
# Epoch 25/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5741 - loss: 1.2763 - top5: 0.9375 - val_accuracy: 0.5571 - val_loss: 1.3555 - val_top5: 0.9036 - learning_rate: 8.4983e-04
# Epoch 26/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5722 - loss: 1.2691 - top5: 0.9388 - val_accuracy: 0.5250 - val_loss: 1.3789 - val_top5: 0.9107 - learning_rate: 8.3457e-04
# Epoch 27/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.5861 - loss: 1.1998 - top5: 0.9426 - val_accuracy: 0.5679 - val_loss: 1.3225 - val_top5: 0.8893 - learning_rate: 8.1871e-04
# Epoch 28/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6120 - loss: 1.2011 - top5: 0.9451 - val_accuracy: 0.5714 - val_loss: 1.3513 - val_top5: 0.9143 - learning_rate: 8.0230e-04
# Epoch 29/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6006 - loss: 1.1979 - top5: 0.9375 - val_accuracy: 0.5393 - val_loss: 1.3842 - val_top5: 0.9000 - learning_rate: 7.8536e-04
# Epoch 30/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6120 - loss: 1.1651 - top5: 0.9464 - val_accuracy: 0.5786 - val_loss: 1.3243 - val_top5: 0.9143 - learning_rate: 7.6791e-04
# Epoch 31/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.6227 - loss: 1.1053 - top5: 0.9546 - val_accuracy: 0.5893 - val_loss: 1.2796 - val_top5: 0.9107 - learning_rate: 7.5000e-04
# Epoch 32/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6536 - loss: 1.0728 - top5: 0.9527 - val_accuracy: 0.6036 - val_loss: 1.2281 - val_top5: 0.9179 - learning_rate: 7.3165e-04
# Epoch 33/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6536 - loss: 1.0462 - top5: 0.9634 - val_accuracy: 0.5821 - val_loss: 1.3097 - val_top5: 0.8964 - learning_rate: 7.1289e-04
# Epoch 34/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6574 - loss: 1.0266 - top5: 0.9603 - val_accuracy: 0.6143 - val_loss: 1.2380 - val_top5: 0.9143 - learning_rate: 6.9376e-04
# Epoch 35/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6650 - loss: 0.9881 - top5: 0.9596 - val_accuracy: 0.6250 - val_loss: 1.2271 - val_top5: 0.9071 - learning_rate: 6.7429e-04
# Epoch 36/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6877 - loss: 0.9472 - top5: 0.9640 - val_accuracy: 0.5857 - val_loss: 1.3960 - val_top5: 0.9036 - learning_rate: 6.5451e-04
# Epoch 37/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.6927 - loss: 0.9439 - top5: 0.9615 - val_accuracy: 0.6250 - val_loss: 1.2278 - val_top5: 0.9143 - learning_rate: 6.3446e-04
# Epoch 38/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7117 - loss: 0.8911 - top5: 0.9685 - val_accuracy: 0.6036 - val_loss: 1.2792 - val_top5: 0.9036 - learning_rate: 6.1418e-04
# Epoch 39/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7079 - loss: 0.8863 - top5: 0.9691 - val_accuracy: 0.6179 - val_loss: 1.2759 - val_top5: 0.9036 - learning_rate: 5.9369e-04
# Epoch 40/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.7237 - loss: 0.8502 - top5: 0.9666 - val_accuracy: 0.6357 - val_loss: 1.2317 - val_top5: 0.9143 - learning_rate: 5.7304e-04
# Epoch 41/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7211 - loss: 0.8615 - top5: 0.9697 - val_accuracy: 0.6464 - val_loss: 1.2326 - val_top5: 0.9071 - learning_rate: 5.5226e-04
# Epoch 42/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7394 - loss: 0.8047 - top5: 0.9710 - val_accuracy: 0.6321 - val_loss: 1.2159 - val_top5: 0.9179 - learning_rate: 5.3140e-04
# Epoch 43/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7539 - loss: 0.7565 - top5: 0.9748 - val_accuracy: 0.6393 - val_loss: 1.2744 - val_top5: 0.9250 - learning_rate: 5.1047e-04
# Epoch 44/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7464 - loss: 0.7341 - top5: 0.9798 - val_accuracy: 0.6607 - val_loss: 1.2230 - val_top5: 0.9286 - learning_rate: 4.8953e-04
# Epoch 45/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7521 - loss: 0.7296 - top5: 0.9811 - val_accuracy: 0.6357 - val_loss: 1.3225 - val_top5: 0.9143 - learning_rate: 4.6860e-04
# Epoch 46/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7748 - loss: 0.6858 - top5: 0.9798 - val_accuracy: 0.6536 - val_loss: 1.2274 - val_top5: 0.9107 - learning_rate: 4.4774e-04
# Epoch 47/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7842 - loss: 0.6630 - top5: 0.9798 - val_accuracy: 0.6250 - val_loss: 1.2807 - val_top5: 0.9286 - learning_rate: 4.2696e-04
# Epoch 48/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7899 - loss: 0.6362 - top5: 0.9817 - val_accuracy: 0.6714 - val_loss: 1.2264 - val_top5: 0.9214 - learning_rate: 4.0631e-04
# Epoch 49/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7937 - loss: 0.6147 - top5: 0.9823 - val_accuracy: 0.6607 - val_loss: 1.2510 - val_top5: 0.9036 - learning_rate: 3.8582e-04
# Epoch 50/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7987 - loss: 0.6009 - top5: 0.9798 - val_accuracy: 0.6393 - val_loss: 1.3530 - val_top5: 0.9143 - learning_rate: 3.6554e-04
# Epoch 51/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8170 - loss: 0.5563 - top5: 0.9861 - val_accuracy: 0.6821 - val_loss: 1.2926 - val_top5: 0.9107 - learning_rate: 3.4549e-04
# Epoch 52/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8139 - loss: 0.5444 - top5: 0.9880 - val_accuracy: 0.6536 - val_loss: 1.3084 - val_top5: 0.9071 - learning_rate: 3.2571e-04
# Epoch 53/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8233 - loss: 0.5254 - top5: 0.9855 - val_accuracy: 0.6786 - val_loss: 1.2772 - val_top5: 0.9214 - learning_rate: 3.0624e-04
# Epoch 54/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8322 - loss: 0.5082 - top5: 0.9855 - val_accuracy: 0.6321 - val_loss: 1.3310 - val_top5: 0.9179 - learning_rate: 2.8711e-04
# Epoch 55/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8360 - loss: 0.4812 - top5: 0.9880 - val_accuracy: 0.6607 - val_loss: 1.3178 - val_top5: 0.9179 - learning_rate: 2.6835e-04
# Epoch 56/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8467 - loss: 0.4746 - top5: 0.9861 - val_accuracy: 0.6500 - val_loss: 1.2930 - val_top5: 0.9179 - learning_rate: 2.5000e-04
# Epoch 57/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8524 - loss: 0.4460 - top5: 0.9893 - val_accuracy: 0.6500 - val_loss: 1.3291 - val_top5: 0.9179 - learning_rate: 2.3209e-04
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 42.
#   conv_lstm_v2 → acc=0.6321  top5=0.9179
#
# ━━━ Transformer ━━━
# Model: "Transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 362)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64, 128)   │     46,464 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 64, 128)   │        256 │ dense[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 128)   │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 128)   │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 128)   │          0 │ add[0][0],        │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64, 512)   │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 512)   │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64, 128)   │     65,664 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64, 512)   │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64, 512)   │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64, 128)   │     65,664 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 64, 512)   │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 512)   │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64, 128)   │     65,664 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64, 512)   │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 512)   │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64, 128)   │     65,664 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256)       │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 128)       │     32,896 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128)       │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 20)        │      2,580 │ dropout_9[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 908,308 (3.46 MB)
#  Trainable params: 908,308 (3.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 79s 782ms/step - accuracy: 0.0555 - loss: 3.0877 - top5: 0.2644 - val_accuracy: 0.1214 - val_loss: 2.9216 - val_top5: 0.4393 - learning_rate: 2.0000e-04
# Epoch 2/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.0820 - loss: 2.9756 - top5: 0.3394 - val_accuracy: 0.1286 - val_loss: 2.8015 - val_top5: 0.4714 - learning_rate: 4.0000e-04
# Epoch 3/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.1085 - loss: 2.8726 - top5: 0.4177 - val_accuracy: 0.1821 - val_loss: 2.6179 - val_top5: 0.5821 - learning_rate: 6.0000e-04
# Epoch 4/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.1457 - loss: 2.7126 - top5: 0.5325 - val_accuracy: 0.2464 - val_loss: 2.3734 - val_top5: 0.6929 - learning_rate: 8.0000e-04
# Epoch 5/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.1577 - loss: 2.6346 - top5: 0.5785 - val_accuracy: 0.2321 - val_loss: 2.3721 - val_top5: 0.7000 - learning_rate: 0.0010
# Epoch 6/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.2290 - loss: 2.3821 - top5: 0.6940 - val_accuracy: 0.2964 - val_loss: 2.1724 - val_top5: 0.7571 - learning_rate: 0.0010
# Epoch 7/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.2498 - loss: 2.2997 - top5: 0.7445 - val_accuracy: 0.3500 - val_loss: 2.0321 - val_top5: 0.8107 - learning_rate: 9.9956e-04
# Epoch 8/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.2814 - loss: 2.1612 - top5: 0.7893 - val_accuracy: 0.3321 - val_loss: 2.0403 - val_top5: 0.7750 - learning_rate: 9.9825e-04
# Epoch 9/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.2965 - loss: 2.1416 - top5: 0.7811 - val_accuracy: 0.4036 - val_loss: 1.8975 - val_top5: 0.8464 - learning_rate: 9.9606e-04
# Epoch 10/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3457 - loss: 1.9653 - top5: 0.8372 - val_accuracy: 0.3500 - val_loss: 2.0236 - val_top5: 0.7929 - learning_rate: 9.9300e-04
# Epoch 11/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.3634 - loss: 1.9335 - top5: 0.8442 - val_accuracy: 0.4393 - val_loss: 1.7175 - val_top5: 0.8750 - learning_rate: 9.8907e-04
# Epoch 12/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3849 - loss: 1.8688 - top5: 0.8530 - val_accuracy: 0.4000 - val_loss: 1.8142 - val_top5: 0.8500 - learning_rate: 9.8429e-04
# Epoch 13/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.4240 - loss: 1.8017 - top5: 0.8675 - val_accuracy: 0.4929 - val_loss: 1.7205 - val_top5: 0.8679 - learning_rate: 9.7866e-04
# Epoch 14/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4088 - loss: 1.7827 - top5: 0.8669 - val_accuracy: 0.4857 - val_loss: 1.5546 - val_top5: 0.8857 - learning_rate: 9.7219e-04
# Epoch 15/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4215 - loss: 1.7809 - top5: 0.8826 - val_accuracy: 0.4321 - val_loss: 1.7764 - val_top5: 0.8536 - learning_rate: 9.6489e-04
# Epoch 16/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4473 - loss: 1.6630 - top5: 0.8883 - val_accuracy: 0.5071 - val_loss: 1.5291 - val_top5: 0.8857 - learning_rate: 9.5677e-04
# Epoch 17/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.4940 - loss: 1.5579 - top5: 0.9136 - val_accuracy: 0.5286 - val_loss: 1.5254 - val_top5: 0.8821 - learning_rate: 9.4786e-04
# Epoch 18/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4795 - loss: 1.5957 - top5: 0.8978 - val_accuracy: 0.5036 - val_loss: 1.5202 - val_top5: 0.8893 - learning_rate: 9.3815e-04
# Epoch 19/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5028 - loss: 1.5421 - top5: 0.9060 - val_accuracy: 0.5500 - val_loss: 1.4051 - val_top5: 0.9107 - learning_rate: 9.2768e-04
# Epoch 20/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5186 - loss: 1.4967 - top5: 0.9129 - val_accuracy: 0.5679 - val_loss: 1.2887 - val_top5: 0.9214 - learning_rate: 9.1646e-04
# Epoch 21/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5338 - loss: 1.4292 - top5: 0.9243 - val_accuracy: 0.5250 - val_loss: 1.5357 - val_top5: 0.8929 - learning_rate: 9.0451e-04
# Epoch 22/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5350 - loss: 1.3801 - top5: 0.9306 - val_accuracy: 0.5679 - val_loss: 1.3849 - val_top5: 0.8893 - learning_rate: 8.9185e-04
# Epoch 23/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5653 - loss: 1.3526 - top5: 0.9268 - val_accuracy: 0.5679 - val_loss: 1.3860 - val_top5: 0.9179 - learning_rate: 8.7850e-04
# Epoch 24/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5817 - loss: 1.2822 - top5: 0.9375 - val_accuracy: 0.5179 - val_loss: 1.4120 - val_top5: 0.8964 - learning_rate: 8.6448e-04
# Epoch 25/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5968 - loss: 1.2687 - top5: 0.9356 - val_accuracy: 0.6071 - val_loss: 1.3276 - val_top5: 0.9000 - learning_rate: 8.4983e-04
# Epoch 26/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5931 - loss: 1.2715 - top5: 0.9388 - val_accuracy: 0.5500 - val_loss: 1.5050 - val_top5: 0.8571 - learning_rate: 8.3457e-04
# Epoch 27/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6391 - loss: 1.1547 - top5: 0.9451 - val_accuracy: 0.5893 - val_loss: 1.3352 - val_top5: 0.9179 - learning_rate: 8.1871e-04
# Epoch 28/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6309 - loss: 1.1473 - top5: 0.9489 - val_accuracy: 0.6357 - val_loss: 1.1934 - val_top5: 0.9214 - learning_rate: 8.0230e-04
# Epoch 29/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6341 - loss: 1.1605 - top5: 0.9476 - val_accuracy: 0.6071 - val_loss: 1.2740 - val_top5: 0.9143 - learning_rate: 7.8536e-04
# Epoch 30/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6435 - loss: 1.0665 - top5: 0.9584 - val_accuracy: 0.6393 - val_loss: 1.2040 - val_top5: 0.9107 - learning_rate: 7.6791e-04
# Epoch 31/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6675 - loss: 0.9966 - top5: 0.9596 - val_accuracy: 0.5821 - val_loss: 1.5183 - val_top5: 0.8929 - learning_rate: 7.5000e-04
# Epoch 32/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6719 - loss: 1.0571 - top5: 0.9577 - val_accuracy: 0.6036 - val_loss: 1.3495 - val_top5: 0.9143 - learning_rate: 7.3165e-04
# Epoch 33/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6574 - loss: 1.0160 - top5: 0.9558 - val_accuracy: 0.6571 - val_loss: 1.2724 - val_top5: 0.8964 - learning_rate: 7.1289e-04
# Epoch 34/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6871 - loss: 0.9563 - top5: 0.9634 - val_accuracy: 0.6464 - val_loss: 1.2061 - val_top5: 0.9250 - learning_rate: 6.9376e-04
# Epoch 35/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7041 - loss: 0.9427 - top5: 0.9685 - val_accuracy: 0.6500 - val_loss: 1.1904 - val_top5: 0.9179 - learning_rate: 6.7429e-04
# Epoch 36/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7375 - loss: 0.8437 - top5: 0.9666 - val_accuracy: 0.6250 - val_loss: 1.3026 - val_top5: 0.9071 - learning_rate: 6.5451e-04
# Epoch 37/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7413 - loss: 0.8131 - top5: 0.9735 - val_accuracy: 0.6536 - val_loss: 1.2000 - val_top5: 0.9107 - learning_rate: 6.3446e-04
# Epoch 38/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7558 - loss: 0.7882 - top5: 0.9729 - val_accuracy: 0.6750 - val_loss: 1.2317 - val_top5: 0.9143 - learning_rate: 6.1418e-04
# Epoch 39/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7842 - loss: 0.6901 - top5: 0.9729 - val_accuracy: 0.6250 - val_loss: 1.2720 - val_top5: 0.9250 - learning_rate: 5.9369e-04
# Epoch 40/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7836 - loss: 0.6713 - top5: 0.9792 - val_accuracy: 0.6607 - val_loss: 1.2322 - val_top5: 0.9214 - learning_rate: 5.7304e-04
# Epoch 41/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7868 - loss: 0.6959 - top5: 0.9767 - val_accuracy: 0.6571 - val_loss: 1.2599 - val_top5: 0.9357 - learning_rate: 5.5226e-04
# Epoch 42/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7943 - loss: 0.6133 - top5: 0.9868 - val_accuracy: 0.6857 - val_loss: 1.2731 - val_top5: 0.9214 - learning_rate: 5.3140e-04
# Epoch 43/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7893 - loss: 0.6113 - top5: 0.9798 - val_accuracy: 0.6321 - val_loss: 1.2079 - val_top5: 0.9357 - learning_rate: 5.1047e-04
# Epoch 44/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8233 - loss: 0.5517 - top5: 0.9868 - val_accuracy: 0.6750 - val_loss: 1.2968 - val_top5: 0.9250 - learning_rate: 4.8953e-04
# Epoch 45/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8246 - loss: 0.5424 - top5: 0.9861 - val_accuracy: 0.6929 - val_loss: 1.2023 - val_top5: 0.9214 - learning_rate: 4.6860e-04
# Epoch 46/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8486 - loss: 0.4793 - top5: 0.9886 - val_accuracy: 0.6750 - val_loss: 1.3213 - val_top5: 0.9250 - learning_rate: 4.4774e-04
# Epoch 47/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8524 - loss: 0.4575 - top5: 0.9912 - val_accuracy: 0.6964 - val_loss: 1.2038 - val_top5: 0.9357 - learning_rate: 4.2696e-04
# Epoch 48/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8587 - loss: 0.4530 - top5: 0.9880 - val_accuracy: 0.6536 - val_loss: 1.1669 - val_top5: 0.9357 - learning_rate: 4.0631e-04
# Epoch 49/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8688 - loss: 0.4006 - top5: 0.9918 - val_accuracy: 0.6929 - val_loss: 1.3249 - val_top5: 0.9429 - learning_rate: 3.8582e-04
# Epoch 50/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8833 - loss: 0.3721 - top5: 0.9918 - val_accuracy: 0.6929 - val_loss: 1.3295 - val_top5: 0.9286 - learning_rate: 3.6554e-04
# Epoch 51/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8808 - loss: 0.3615 - top5: 0.9912 - val_accuracy: 0.7000 - val_loss: 1.2982 - val_top5: 0.9286 - learning_rate: 3.4549e-04
# Epoch 52/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9016 - loss: 0.3114 - top5: 0.9912 - val_accuracy: 0.7143 - val_loss: 1.2544 - val_top5: 0.9321 - learning_rate: 3.2571e-04
# Epoch 53/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9085 - loss: 0.2843 - top5: 0.9950 - val_accuracy: 0.7107 - val_loss: 1.3435 - val_top5: 0.9357 - learning_rate: 3.0624e-04
# Epoch 54/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9230 - loss: 0.2575 - top5: 0.9931 - val_accuracy: 0.6964 - val_loss: 1.5104 - val_top5: 0.9179 - learning_rate: 2.8711e-04
# Epoch 55/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9281 - loss: 0.2246 - top5: 0.9968 - val_accuracy: 0.6893 - val_loss: 1.4995 - val_top5: 0.9286 - learning_rate: 2.6835e-04
# Epoch 56/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9356 - loss: 0.2102 - top5: 0.9956 - val_accuracy: 0.6929 - val_loss: 1.4853 - val_top5: 0.9286 - learning_rate: 2.5000e-04
# Epoch 57/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9394 - loss: 0.1984 - top5: 0.9943 - val_accuracy: 0.7179 - val_loss: 1.3283 - val_top5: 0.9321 - learning_rate: 2.3209e-04
# Epoch 58/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9502 - loss: 0.1827 - top5: 0.9937 - val_accuracy: 0.6929 - val_loss: 1.4742 - val_top5: 0.9214 - learning_rate: 2.1464e-04
# Epoch 59/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9521 - loss: 0.1717 - top5: 0.9968 - val_accuracy: 0.7071 - val_loss: 1.4451 - val_top5: 0.9321 - learning_rate: 1.9770e-04
# Epoch 60/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9596 - loss: 0.1364 - top5: 0.9962 - val_accuracy: 0.7393 - val_loss: 1.4314 - val_top5: 0.9357 - learning_rate: 1.8129e-04
# Epoch 61/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9514 - loss: 0.1397 - top5: 0.9981 - val_accuracy: 0.7071 - val_loss: 1.5432 - val_top5: 0.9321 - learning_rate: 1.6543e-04
# Epoch 62/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9697 - loss: 0.1137 - top5: 0.9968 - val_accuracy: 0.6893 - val_loss: 1.6910 - val_top5: 0.9321 - learning_rate: 1.5017e-04
# Epoch 63/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9659 - loss: 0.1189 - top5: 0.9987 - val_accuracy: 0.7250 - val_loss: 1.4511 - val_top5: 0.9250 - learning_rate: 1.3552e-04
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 48.
#   transformer → acc=0.6536  top5=0.9357
#
# ━━━ Modern RNN ━━━
# Model: "Modern_RNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 362)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64, 128)        │        46,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization             │ (None, 64, 128)        │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 64, 256)        │       198,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_1           │ (None, 64, 256)        │           512 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 256)            │       296,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 20)             │         2,580 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 643,092 (2.45 MB)
#  Trainable params: 643,092 (2.45 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.0536 - loss: 3.0496 - top5: 0.2972 - val_accuracy: 0.1214 - val_loss: 2.9078 - val_top5: 0.4214 - learning_rate: 2.0000e-04
# Epoch 2/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.1003 - loss: 2.9240 - top5: 0.3735 - val_accuracy: 0.1286 - val_loss: 2.7591 - val_top5: 0.5321 - learning_rate: 4.0000e-04
# Epoch 3/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.1369 - loss: 2.7799 - top5: 0.4978 - val_accuracy: 0.2107 - val_loss: 2.5615 - val_top5: 0.6179 - learning_rate: 6.0000e-04
# Epoch 4/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.1937 - loss: 2.6113 - top5: 0.5855 - val_accuracy: 0.2571 - val_loss: 2.4269 - val_top5: 0.6536 - learning_rate: 8.0000e-04
# Epoch 5/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.2416 - loss: 2.4282 - top5: 0.6555 - val_accuracy: 0.2821 - val_loss: 2.2112 - val_top5: 0.7250 - learning_rate: 0.0010
# Epoch 6/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.2940 - loss: 2.2419 - top5: 0.7319 - val_accuracy: 0.3429 - val_loss: 1.9546 - val_top5: 0.7679 - learning_rate: 0.0010
# Epoch 7/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.3243 - loss: 2.0771 - top5: 0.7773 - val_accuracy: 0.4036 - val_loss: 1.8501 - val_top5: 0.8071 - learning_rate: 9.9956e-04
# Epoch 8/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.3785 - loss: 1.9563 - top5: 0.8000 - val_accuracy: 0.4143 - val_loss: 1.8196 - val_top5: 0.8250 - learning_rate: 9.9825e-04
# Epoch 9/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.4139 - loss: 1.8306 - top5: 0.8397 - val_accuracy: 0.4893 - val_loss: 1.5879 - val_top5: 0.8571 - learning_rate: 9.9606e-04
# Epoch 10/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4574 - loss: 1.6616 - top5: 0.8681 - val_accuracy: 0.4393 - val_loss: 1.6724 - val_top5: 0.8536 - learning_rate: 9.9300e-04
# Epoch 11/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5022 - loss: 1.6005 - top5: 0.8890 - val_accuracy: 0.4214 - val_loss: 1.6317 - val_top5: 0.8750 - learning_rate: 9.8907e-04
# Epoch 12/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4946 - loss: 1.5168 - top5: 0.9016 - val_accuracy: 0.5107 - val_loss: 1.4902 - val_top5: 0.8857 - learning_rate: 9.8429e-04
# Epoch 13/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5224 - loss: 1.4780 - top5: 0.9041 - val_accuracy: 0.5643 - val_loss: 1.4005 - val_top5: 0.8929 - learning_rate: 9.7866e-04
# Epoch 14/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5615 - loss: 1.3908 - top5: 0.9148 - val_accuracy: 0.5536 - val_loss: 1.4582 - val_top5: 0.8750 - learning_rate: 9.7219e-04
# Epoch 15/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5760 - loss: 1.2937 - top5: 0.9224 - val_accuracy: 0.5786 - val_loss: 1.3348 - val_top5: 0.9000 - learning_rate: 9.6489e-04
# Epoch 16/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6151 - loss: 1.2108 - top5: 0.9363 - val_accuracy: 0.5929 - val_loss: 1.4343 - val_top5: 0.9143 - learning_rate: 9.5677e-04
# Epoch 17/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6196 - loss: 1.1683 - top5: 0.9382 - val_accuracy: 0.5679 - val_loss: 1.4385 - val_top5: 0.9071 - learning_rate: 9.4786e-04
# Epoch 18/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6341 - loss: 1.1439 - top5: 0.9438 - val_accuracy: 0.6143 - val_loss: 1.2749 - val_top5: 0.9071 - learning_rate: 9.3815e-04
# Epoch 19/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6549 - loss: 1.0428 - top5: 0.9464 - val_accuracy: 0.6321 - val_loss: 1.2260 - val_top5: 0.9250 - learning_rate: 9.2768e-04
# Epoch 20/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6574 - loss: 1.0524 - top5: 0.9533 - val_accuracy: 0.6250 - val_loss: 1.2145 - val_top5: 0.9036 - learning_rate: 9.1646e-04
# Epoch 21/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6738 - loss: 0.9988 - top5: 0.9533 - val_accuracy: 0.6214 - val_loss: 1.2429 - val_top5: 0.9179 - learning_rate: 9.0451e-04
# Epoch 22/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7174 - loss: 0.8933 - top5: 0.9703 - val_accuracy: 0.6357 - val_loss: 1.3157 - val_top5: 0.9179 - learning_rate: 8.9185e-04
# Epoch 23/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7110 - loss: 0.8993 - top5: 0.9634 - val_accuracy: 0.5750 - val_loss: 1.3583 - val_top5: 0.9000 - learning_rate: 8.7850e-04
# Epoch 24/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7287 - loss: 0.8337 - top5: 0.9703 - val_accuracy: 0.6036 - val_loss: 1.2990 - val_top5: 0.9250 - learning_rate: 8.6448e-04
# Epoch 25/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7161 - loss: 0.8364 - top5: 0.9659 - val_accuracy: 0.6429 - val_loss: 1.2270 - val_top5: 0.9107 - learning_rate: 8.4983e-04
# Epoch 26/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7451 - loss: 0.8088 - top5: 0.9722 - val_accuracy: 0.6143 - val_loss: 1.2691 - val_top5: 0.9250 - learning_rate: 8.3457e-04
# Epoch 27/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.7464 - loss: 0.7509 - top5: 0.9691 - val_accuracy: 0.6643 - val_loss: 1.2232 - val_top5: 0.9214 - learning_rate: 8.1871e-04
# Epoch 28/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7697 - loss: 0.6913 - top5: 0.9798 - val_accuracy: 0.6429 - val_loss: 1.2206 - val_top5: 0.9250 - learning_rate: 8.0230e-04
# Epoch 29/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.7817 - loss: 0.6785 - top5: 0.9792 - val_accuracy: 0.6536 - val_loss: 1.2893 - val_top5: 0.9286 - learning_rate: 7.8536e-04
# Epoch 30/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.7868 - loss: 0.6445 - top5: 0.9792 - val_accuracy: 0.6750 - val_loss: 1.1597 - val_top5: 0.9286 - learning_rate: 7.6791e-04
# Epoch 31/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8114 - loss: 0.5713 - top5: 0.9849 - val_accuracy: 0.6607 - val_loss: 1.2727 - val_top5: 0.9179 - learning_rate: 7.5000e-04
# Epoch 32/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8145 - loss: 0.5828 - top5: 0.9880 - val_accuracy: 0.6500 - val_loss: 1.2837 - val_top5: 0.9321 - learning_rate: 7.3165e-04
# Epoch 33/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8278 - loss: 0.5220 - top5: 0.9823 - val_accuracy: 0.6786 - val_loss: 1.2893 - val_top5: 0.9250 - learning_rate: 7.1289e-04
# Epoch 34/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8246 - loss: 0.5507 - top5: 0.9874 - val_accuracy: 0.6571 - val_loss: 1.2159 - val_top5: 0.9321 - learning_rate: 6.9376e-04
# Epoch 35/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8328 - loss: 0.5026 - top5: 0.9893 - val_accuracy: 0.6964 - val_loss: 1.2385 - val_top5: 0.9321 - learning_rate: 6.7429e-04
# Epoch 36/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8631 - loss: 0.4257 - top5: 0.9924 - val_accuracy: 0.6964 - val_loss: 1.2713 - val_top5: 0.9250 - learning_rate: 6.5451e-04
# Epoch 37/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8656 - loss: 0.4332 - top5: 0.9931 - val_accuracy: 0.6714 - val_loss: 1.3265 - val_top5: 0.9250 - learning_rate: 6.3446e-04
# Epoch 38/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8625 - loss: 0.4249 - top5: 0.9943 - val_accuracy: 0.6714 - val_loss: 1.3115 - val_top5: 0.9214 - learning_rate: 6.1418e-04
# Epoch 39/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8726 - loss: 0.3997 - top5: 0.9962 - val_accuracy: 0.6679 - val_loss: 1.3057 - val_top5: 0.9500 - learning_rate: 5.9369e-04
# Epoch 40/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8877 - loss: 0.3578 - top5: 0.9968 - val_accuracy: 0.6607 - val_loss: 1.4332 - val_top5: 0.9321 - learning_rate: 5.7304e-04
# Epoch 41/80
# ...
# Epoch 11/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3161 - loss: 2.0198 - top5: 0.8385 - val_accuracy: 0.3786 - val_loss: 1.8918 - val_top5: 0.8393 - learning_rate: 9.8907e-04
# Epoch 12/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3350 - loss: 2.0093 - top5: 0.8227 - val_accuracy: 0.3643 - val_loss: 1.8141 - val_top5: 0.8607 - learning_rate: 9.8429e-04
# Epoch 13/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3609 - loss: 1.9293 - top5: 0.8353 - val_accuracy: 0.3750 - val_loss: 1.9929 - val_top5: 0.8036 - learning_rate: 9.7866e-04
# Epoch 14/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.3628 - loss: 1.8765 - top5: 0.8530 - val_accuracy: 0.3893 - val_loss: 1.8472 - val_top5: 0.8464 - learning_rate: 9.7219e-04
# Epoch 15/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.3741 - loss: 1.8828 - top5: 0.8593 - val_accuracy: 0.4321 - val_loss: 1.7749 - val_top5: 0.8679 - learning_rate: 9.6489e-04
# Epoch 16/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.4126 - loss: 1.7767 - top5: 0.8738 - val_accuracy: 0.4714 - val_loss: 1.6214 - val_top5: 0.8750 - learning_rate: 9.5677e-04
# Epoch 17/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4158 - loss: 1.7691 - top5: 0.8726 - val_accuracy: 0.4500 - val_loss: 1.5958 - val_top5: 0.8857 - learning_rate: 9.4786e-04
# Epoch 18/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4114 - loss: 1.7381 - top5: 0.8820 - val_accuracy: 0.4429 - val_loss: 1.6453 - val_top5: 0.8893 - learning_rate: 9.3815e-04
# Epoch 19/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4536 - loss: 1.6400 - top5: 0.8883 - val_accuracy: 0.4286 - val_loss: 1.7208 - val_top5: 0.8464 - learning_rate: 9.2768e-04
# Epoch 20/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.4650 - loss: 1.6089 - top5: 0.8864 - val_accuracy: 0.4821 - val_loss: 1.5536 - val_top5: 0.8964 - learning_rate: 9.1646e-04
# Epoch 21/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4782 - loss: 1.5805 - top5: 0.8997 - val_accuracy: 0.4500 - val_loss: 1.7665 - val_top5: 0.8250 - learning_rate: 9.0451e-04
# Epoch 22/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4953 - loss: 1.5312 - top5: 0.9098 - val_accuracy: 0.4750 - val_loss: 1.5557 - val_top5: 0.8821 - learning_rate: 8.9185e-04
# Epoch 23/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5180 - loss: 1.5176 - top5: 0.9161 - val_accuracy: 0.5500 - val_loss: 1.5086 - val_top5: 0.8929 - learning_rate: 8.7850e-04
# Epoch 24/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5142 - loss: 1.4965 - top5: 0.9199 - val_accuracy: 0.5464 - val_loss: 1.4805 - val_top5: 0.8821 - learning_rate: 8.6448e-04
# Epoch 25/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5489 - loss: 1.4201 - top5: 0.9306 - val_accuracy: 0.5250 - val_loss: 1.4150 - val_top5: 0.9071 - learning_rate: 8.4983e-04
# Epoch 26/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5521 - loss: 1.3789 - top5: 0.9287 - val_accuracy: 0.5250 - val_loss: 1.4249 - val_top5: 0.9071 - learning_rate: 8.3457e-04
# Epoch 27/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5603 - loss: 1.3289 - top5: 0.9350 - val_accuracy: 0.5250 - val_loss: 1.4417 - val_top5: 0.9071 - learning_rate: 8.1871e-04
# Epoch 28/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5741 - loss: 1.3130 - top5: 0.9388 - val_accuracy: 0.5179 - val_loss: 1.5229 - val_top5: 0.8857 - learning_rate: 8.0230e-04
# Epoch 29/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5741 - loss: 1.3168 - top5: 0.9375 - val_accuracy: 0.4964 - val_loss: 1.5753 - val_top5: 0.9036 - learning_rate: 7.8536e-04
# Epoch 30/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5779 - loss: 1.3037 - top5: 0.9470 - val_accuracy: 0.5571 - val_loss: 1.4429 - val_top5: 0.8893 - learning_rate: 7.6791e-04
# Epoch 31/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5975 - loss: 1.2509 - top5: 0.9394 - val_accuracy: 0.5750 - val_loss: 1.3975 - val_top5: 0.9143 - learning_rate: 7.5000e-04
# Epoch 32/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6000 - loss: 1.2499 - top5: 0.9401 - val_accuracy: 0.5464 - val_loss: 1.4201 - val_top5: 0.9107 - learning_rate: 7.3165e-04
# Epoch 33/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6177 - loss: 1.1705 - top5: 0.9533 - val_accuracy: 0.5393 - val_loss: 1.4686 - val_top5: 0.9071 - learning_rate: 7.1289e-04
# Epoch 34/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6505 - loss: 1.0812 - top5: 0.9571 - val_accuracy: 0.5893 - val_loss: 1.3803 - val_top5: 0.9143 - learning_rate: 6.9376e-04
# Epoch 35/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6252 - loss: 1.1149 - top5: 0.9552 - val_accuracy: 0.5500 - val_loss: 1.4215 - val_top5: 0.9107 - learning_rate: 6.7429e-04
# Epoch 36/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6555 - loss: 1.0141 - top5: 0.9621 - val_accuracy: 0.5464 - val_loss: 1.5499 - val_top5: 0.9000 - learning_rate: 6.5451e-04
# Epoch 37/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6650 - loss: 1.0752 - top5: 0.9603 - val_accuracy: 0.5357 - val_loss: 1.3996 - val_top5: 0.9143 - learning_rate: 6.3446e-04
# Epoch 38/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6789 - loss: 0.9802 - top5: 0.9685 - val_accuracy: 0.6000 - val_loss: 1.4493 - val_top5: 0.8964 - learning_rate: 6.1418e-04
# Epoch 39/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6902 - loss: 0.9698 - top5: 0.9697 - val_accuracy: 0.6071 - val_loss: 1.4701 - val_top5: 0.8786 - learning_rate: 5.9369e-04
# Epoch 40/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7073 - loss: 0.9321 - top5: 0.9691 - val_accuracy: 0.6071 - val_loss: 1.3851 - val_top5: 0.8786 - learning_rate: 5.7304e-04
# Epoch 41/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6826 - loss: 0.9967 - top5: 0.9703 - val_accuracy: 0.6071 - val_loss: 1.3573 - val_top5: 0.9071 - learning_rate: 5.5226e-04
# Epoch 42/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.7174 - loss: 0.8932 - top5: 0.9748 - val_accuracy: 0.6321 - val_loss: 1.3349 - val_top5: 0.9143 - learning_rate: 5.3140e-04
# Epoch 43/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7356 - loss: 0.8127 - top5: 0.9729 - val_accuracy: 0.6036 - val_loss: 1.4271 - val_top5: 0.8857 - learning_rate: 5.1047e-04
# Epoch 44/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7552 - loss: 0.7586 - top5: 0.9804 - val_accuracy: 0.6036 - val_loss: 1.4747 - val_top5: 0.8857 - learning_rate: 4.8953e-04
# Epoch 45/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7464 - loss: 0.7611 - top5: 0.9849 - val_accuracy: 0.6250 - val_loss: 1.3549 - val_top5: 0.9143 - learning_rate: 4.6860e-04
# Epoch 46/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7653 - loss: 0.7265 - top5: 0.9798 - val_accuracy: 0.5964 - val_loss: 1.4616 - val_top5: 0.9036 - learning_rate: 4.4774e-04
# Epoch 47/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7729 - loss: 0.6919 - top5: 0.9830 - val_accuracy: 0.6286 - val_loss: 1.4811 - val_top5: 0.8964 - learning_rate: 4.2696e-04
# Epoch 48/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7868 - loss: 0.6570 - top5: 0.9861 - val_accuracy: 0.6107 - val_loss: 1.4751 - val_top5: 0.9000 - learning_rate: 4.0631e-04
# Epoch 49/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7975 - loss: 0.6206 - top5: 0.9842 - val_accuracy: 0.5857 - val_loss: 1.5797 - val_top5: 0.9036 - learning_rate: 3.8582e-04
# Epoch 50/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8025 - loss: 0.6145 - top5: 0.9868 - val_accuracy: 0.6250 - val_loss: 1.5058 - val_top5: 0.8964 - learning_rate: 3.6554e-04
# Epoch 51/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8196 - loss: 0.5602 - top5: 0.9886 - val_accuracy: 0.6250 - val_loss: 1.5724 - val_top5: 0.9071 - learning_rate: 3.4549e-04
# Epoch 52/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8132 - loss: 0.5596 - top5: 0.9905 - val_accuracy: 0.6214 - val_loss: 1.5952 - val_top5: 0.9071 - learning_rate: 3.2571e-04
# Epoch 53/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8322 - loss: 0.5075 - top5: 0.9905 - val_accuracy: 0.6464 - val_loss: 1.5275 - val_top5: 0.9036 - learning_rate: 3.0624e-04
# Epoch 54/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8473 - loss: 0.4810 - top5: 0.9886 - val_accuracy: 0.6393 - val_loss: 1.6053 - val_top5: 0.9000 - learning_rate: 2.8711e-04
# Epoch 55/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8530 - loss: 0.4342 - top5: 0.9950 - val_accuracy: 0.6429 - val_loss: 1.6003 - val_top5: 0.8857 - learning_rate: 2.6835e-04
# Epoch 56/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8700 - loss: 0.4049 - top5: 0.9956 - val_accuracy: 0.6429 - val_loss: 1.7268 - val_top5: 0.8857 - learning_rate: 2.5000e-04
# Epoch 57/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8562 - loss: 0.4404 - top5: 0.9886 - val_accuracy: 0.6500 - val_loss: 1.6660 - val_top5: 0.9143 - learning_rate: 2.3209e-04
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 42.
#   hybrid_cnn_transformer → acc=0.6321  top5=0.9143
#
# ━━━ DeepARTMAP Proxy ━━━
# Model: "DeepARTMAP_Proxy"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 362)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 23168)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    11,862,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 20)             │         5,140 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,998,996 (45.77 MB)
#  Trainable params: 11,998,996 (45.77 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 189ms/step - accuracy: 0.1066 - loss: 3.9680 - top5: 0.3842 - val_accuracy: 0.1714 - val_loss: 2.9542 - val_top5: 0.5036 - learning_rate: 2.0000e-04
# Epoch 2/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2391 - loss: 3.4771 - top5: 0.5678 - val_accuracy: 0.1393 - val_loss: 4.1520 - val_top5: 0.4750 - learning_rate: 4.0000e-04
# Epoch 3/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2511 - loss: 3.4732 - top5: 0.5880 - val_accuracy: 0.2179 - val_loss: 3.3626 - val_top5: 0.5643 - learning_rate: 6.0000e-04
# Epoch 4/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2656 - loss: 3.5492 - top5: 0.6233 - val_accuracy: 0.2321 - val_loss: 3.4183 - val_top5: 0.5714 - learning_rate: 8.0000e-04
# Epoch 5/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.2789 - loss: 3.2743 - top5: 0.6492 - val_accuracy: 0.2000 - val_loss: 3.0686 - val_top5: 0.5500 - learning_rate: 0.0010
# Epoch 6/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3413 - loss: 2.7176 - top5: 0.6896 - val_accuracy: 0.2036 - val_loss: 3.6665 - val_top5: 0.5500 - learning_rate: 0.0010
# Epoch 7/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3085 - loss: 2.6405 - top5: 0.6871 - val_accuracy: 0.1750 - val_loss: 3.3704 - val_top5: 0.5607 - learning_rate: 9.9956e-04
# Epoch 8/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.3521 - loss: 2.3138 - top5: 0.7319 - val_accuracy: 0.2571 - val_loss: 3.1057 - val_top5: 0.5929 - learning_rate: 9.9825e-04
# Epoch 9/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4215 - loss: 2.0458 - top5: 0.7968 - val_accuracy: 0.2321 - val_loss: 2.6993 - val_top5: 0.6821 - learning_rate: 9.9606e-04
# Epoch 10/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4656 - loss: 1.9494 - top5: 0.8057 - val_accuracy: 0.2107 - val_loss: 3.1076 - val_top5: 0.6321 - learning_rate: 9.9300e-04
# Epoch 11/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5287 - loss: 1.6841 - top5: 0.8479 - val_accuracy: 0.2714 - val_loss: 3.0229 - val_top5: 0.6714 - learning_rate: 9.8907e-04
# Epoch 12/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5584 - loss: 1.5484 - top5: 0.8890 - val_accuracy: 0.2929 - val_loss: 2.7559 - val_top5: 0.7143 - learning_rate: 9.8429e-04
# Epoch 13/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5609 - loss: 1.4578 - top5: 0.8877 - val_accuracy: 0.2893 - val_loss: 3.0420 - val_top5: 0.6964 - learning_rate: 9.7866e-04
# Epoch 14/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.6265 - loss: 1.2460 - top5: 0.9199 - val_accuracy: 0.3000 - val_loss: 2.5361 - val_top5: 0.7179 - learning_rate: 9.7219e-04
# Epoch 15/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6871 - loss: 1.1018 - top5: 0.9338 - val_accuracy: 0.3107 - val_loss: 2.7723 - val_top5: 0.7393 - learning_rate: 9.6489e-04
# Epoch 16/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7155 - loss: 1.0278 - top5: 0.9445 - val_accuracy: 0.3107 - val_loss: 2.9105 - val_top5: 0.7500 - learning_rate: 9.5677e-04
# Epoch 17/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7230 - loss: 0.9920 - top5: 0.9426 - val_accuracy: 0.3464 - val_loss: 2.5946 - val_top5: 0.7607 - learning_rate: 9.4786e-04
# Epoch 18/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7470 - loss: 0.8694 - top5: 0.9691 - val_accuracy: 0.3179 - val_loss: 2.8033 - val_top5: 0.7321 - learning_rate: 9.3815e-04
# Epoch 19/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7659 - loss: 0.8345 - top5: 0.9647 - val_accuracy: 0.3750 - val_loss: 2.8246 - val_top5: 0.7429 - learning_rate: 9.2768e-04
# Epoch 20/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7729 - loss: 0.7763 - top5: 0.9653 - val_accuracy: 0.3464 - val_loss: 3.0844 - val_top5: 0.7464 - learning_rate: 9.1646e-04
# Epoch 21/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8076 - loss: 0.6682 - top5: 0.9785 - val_accuracy: 0.3357 - val_loss: 3.2682 - val_top5: 0.7714 - learning_rate: 9.0451e-04
# Epoch 22/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8246 - loss: 0.6373 - top5: 0.9779 - val_accuracy: 0.3607 - val_loss: 3.2831 - val_top5: 0.7607 - learning_rate: 8.9185e-04
# Epoch 23/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8265 - loss: 0.5880 - top5: 0.9817 - val_accuracy: 0.3357 - val_loss: 3.3603 - val_top5: 0.7107 - learning_rate: 8.7850e-04
# Epoch 24/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8410 - loss: 0.5427 - top5: 0.9868 - val_accuracy: 0.3357 - val_loss: 3.2717 - val_top5: 0.7607 - learning_rate: 8.6448e-04
# Epoch 25/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8530 - loss: 0.5229 - top5: 0.9836 - val_accuracy: 0.3893 - val_loss: 3.1132 - val_top5: 0.7893 - learning_rate: 8.4983e-04
# Epoch 26/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8669 - loss: 0.4893 - top5: 0.9905 - val_accuracy: 0.4179 - val_loss: 3.3086 - val_top5: 0.7679 - learning_rate: 8.3457e-04
# Epoch 27/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8625 - loss: 0.4781 - top5: 0.9868 - val_accuracy: 0.3357 - val_loss: 3.3478 - val_top5: 0.7393 - learning_rate: 8.1871e-04
# Epoch 28/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9041 - loss: 0.3693 - top5: 0.9918 - val_accuracy: 0.4036 - val_loss: 3.1312 - val_top5: 0.7536 - learning_rate: 8.0230e-04
# Epoch 29/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8890 - loss: 0.3900 - top5: 0.9912 - val_accuracy: 0.3679 - val_loss: 3.1179 - val_top5: 0.7571 - learning_rate: 7.8536e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 14.
#   deep_artmap_proxy → acc=0.3000  top5=0.7179
# 0

# %%
# ============================================================
# [7/7] ENSEMBLE + RESULTS
# ============================================================
print("\n[7/7] Ensemble & results...")

w = np.array([a1, a2, a3, a4], dtype=np.float64)
w /= w.sum()
print(f"  Weights: ConvLSTM={w[0]:.3f}  Transformer={w[1]:.3f}  Modern RNN={w[2]:.3f}  Hybrid={w[3]:.3f}")

p_ens  = w[0]*p1 + w[1]*p2 + w[2]*p3 + w[3]*p4
y_true = np.argmax(y_vl, axis=1)
y_pred = np.argmax(p_ens, axis=1)

ens_acc  = float(np.mean(y_pred == y_true))
ens_top5 = float(np.mean(
    [y_true[i] in np.argsort(p_ens[i])[-5:] for i in range(len(y_true))]
))

print(f"\n  Ensemble Acc  : {ens_acc:.4f}")
print(f"  Ensemble Top-5: {ens_top5:.4f}")

results = pd.DataFrame({
    'Model': ['ConvLSTM_v2', 'Transformer', 'Modern RNN', 'Hybrid', 'Ensemble'],
    'Acc':   [a1, a2, a3, a4, ens_acc],
    'Top5':  [t1, t2, t3, t4, ens_top5],
})
print("\n" + results.to_string(index=False))

# ── Final plots ──────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

x_ = np.arange(len(results)); bw = 0.35
axes[0].bar(x_ - bw/2, results['Acc'],  bw, label='Accuracy',  alpha=0.85)
axes[0].bar(x_ + bw/2, results['Top5'], bw, label='Top-5 Acc', alpha=0.85)
axes[0].set_xticks(x_); axes[0].set_xticklabels(results['Model'], rotation=10)
axes[0].set_ylim(0, 1); axes[0].set_ylabel('Score')
axes[0].set_title('Model Comparison'); axes[0].legend()
axes[0].grid(True, alpha=0.3, axis='y')

per_cls = [float(np.mean(y_pred[y_true==i]==i)) if (y_true==i).sum()>0 else 0.0
           for i in range(n_cls)]
axes[1].bar(range(n_cls), sorted(per_cls, reverse=True), alpha=0.75, width=1.0)
axes[1].axhline(ens_acc, color='red', ls='--', lw=2, label=f'Mean {ens_acc:.3f}')
axes[1].set_xlabel('Class (sorted)'); axes[1].set_ylabel('Accuracy')
axes[1].set_title('Per-Class Accuracy'); axes[1].legend()
axes[1].grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig(CKPT_DIR / 'final_results.png', dpi=120)
plt.close()

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(cm, cmap='Blues', ax=ax, xticklabels=False, yticklabels=False)
ax.set_xlabel('Predicted'); ax.set_ylabel('True')
ax.set_title(f'Confusion Matrix ({n_cls} classes)  Acc={ens_acc:.3f}')
plt.tight_layout()
plt.savefig(CKPT_DIR / 'confusion_matrix.png', dpi=120)
plt.close()

# ── Sample predictions ────────────────────────────────────────
print("\n" + "=" * 65)
print("SAMPLE PREDICTIONS")
print("=" * 65)
for i in np.random.choice(len(y_true), min(15, len(y_true)), replace=False):
    tl = le.inverse_transform([y_true[i]])[0]
    pl = le.inverse_transform([y_pred[i]])[0]
    c  = float(p_ens[i, y_pred[i]])
    top5_labels = le.inverse_transform(np.argsort(p_ens[i])[-5:][::-1])
    print(f"  {'✓' if tl==pl else '✗'}  True: {tl:<20s}  "
          f"Pred: {pl:<20s}  Conf: {c:.3f}")

# ── Save all ───────────────────────────────────────────────────
np.save(CKPT_DIR / 'ensemble_preds.npy', p_ens)
np.save(CKPT_DIR / 'val_labels.npy', y_vl)

with open(CKPT_DIR / 'results.json', 'w') as f:
    json.dump({
        'n_classes': int(n_cls), 'feat_dim': FEAT_DIM,
        'n_train': int(len(X_tr)), 'n_val': int(len(X_vl)),
        'conv_lstm_acc': a1, 'transformer_acc': a2, 'modern_rnn_acc': a3,
        'hybrid_acc': a4,
        'ensemble_acc': ens_acc, 'ensemble_top5': ens_top5,
        'weights': w.tolist(), 'label_classes': le.classes_.tolist(),
    }, f, indent=2)

print(f"\n{'='*65}")
print(f"COMPLETE — saved to {CKPT_DIR}")
print(f"{'='*65}")
# Out:
# [7/7] Ensemble & results...
#   Weights: ConvLSTM=0.244  Transformer=0.252  Modern RNN=0.260  Hybrid=0.244
#
#   Ensemble Acc  : 0.7214
#   Ensemble Top-5: 0.9429
#
#       Model      Acc     Top5
# ConvLSTM_v2 0.632143 0.917857
# Transformer 0.653571 0.935714
#  Modern RNN 0.675000 0.928571
#      Hybrid 0.632143 0.914286
#    Ensemble 0.721429 0.942857
#
# =================================================================
# SAMPLE PREDICTIONS
# =================================================================
#   ✗  True: lamp                  Pred: snack                 Conf: 0.581
#   ✓  True: black                 Pred: black                 Conf: 0.619
#   ✗  True: lamp                  Pred: shhh                  Conf: 0.659
#   ✗  True: snack                 Pred: horse                 Conf: 0.382
#   ✗  True: close                 Pred: snack                 Conf: 0.431
#   ✓  True: tomorrow              Pred: tomorrow              Conf: 0.950
#   ✓  True: minemy                Pred: minemy                Conf: 0.939
#   ✓  True: dry                   Pred: dry                   Conf: 0.361
#   ✓  True: home                  Pred: home                  Conf: 0.973
#   ✗  True: lamp                  Pred: boy                   Conf: 0.358
#   ✓  True: cat                   Pred: cat                   Conf: 0.980
#   ✓  True: home                  Pred: home                  Conf: 0.742
#   ✗  True: down                  Pred: time                  Conf: 0.356
#   ✗  True: ride                  Pred: arm                   Conf: 0.175
#   ✓  True: rain                  Pred: rain                  Conf: 0.926
#
# =================================================================
# COMPLETE — saved to /content/drive/MyDrive/DATA/asl-signs/checkpoints
# =================================================================

# %% [markdown]
# ## Conclusion
#
# This project successfully developed and evaluated multiple deep learning architectures for Sign Language Recognition (SLR) using MediaPipe holistic landmarks. By comparing the performance of a Conv1D-LSTM, a Transformer, and a Temporal Convolutional Network (TCN), we created a weighted ensemble model that achieved the highest overall accuracy of **~71.1%** and a robust Top-5 accuracy of **~93.9%** across a 20-class subset.
#
# ### Key Findings and Ongoing Improvements
#
# Through continuous experimentation, we identified critical insights that shaped the final pipeline:
#
# 1.  **Ignoring the Z-Channel:** The z-coordinates (depth) provided by MediaPipe's single-camera tracking are estimations rather than exact physical measurements. We discovered that dropping the z-channel and relying exclusively on the highly accurate x and y spatial coordinates leads to a much more stable feature set (reducing dimensionality to 362). This prevented the models from overfitting to depth artifacts and allowed the Transformer model to achieve a very strong standalone accuracy of 70%.
# 2.  **Model Architecture Discrepancies:** While the Transformer and ConvLSTM_v2 adapted well to the sequence data, the TCN model struggled significantly, achieving near-random accuracy (~6.8%). This indicates that the current dilated convolution setup requires substantial hyperparameter tuning or architectural revision to effectively capture the complex spatial-temporal relationships of sign language compared to attention mechanisms or recurrent units.
# 3.  **Ensemble Robustness:** Despite the complete failure of the TCN model, the ensemble weighting mechanism successfully identified the underperforming model and assigned it a very low weight (~0.049). By heavily relying on the Transformer (~0.504) and ConvLSTM (~0.447), the ensemble managed to slightly edge out the best individual model, proving the resilience of the ensembling approach.
#
# By systematically addressing sensor noise and leveraging ensemble techniques, this system establishes a strong foundation for a reliable, real-time sign language translation tool, aligning with our goal of using AI as an equalizer and enabler for the DHoH community.

# %% [markdown]
# ## Resources & Future Work: Hybrid Architectures
#
# *   **Reference:** [Hoyeol Sohn's 2nd Place Solution - ASL Fingerspelling](https://www.kaggle.com/competitions/asl-fingerspelling/discussion/434620)
#
# **Hybrid Resolution Approach:**
# Drawing inspiration from top-performing models in the ASL Fingerspelling competition, future iterations of this project could integrate a "Hybrid Resolution" architecture. This approach, successfully used to bridge Automatic Speech Recognition (ASR) techniques with sign language data, involves:
#
# *   **Combining Local and Global Context:** Fusing 1D CNNs (for local, high-resolution temporal feature extraction, capturing rapid finger movements) with Transformers or Conformers (for global context and semantic understanding).
# *   **Multi-Resolution Temporal Processing:** Processing the spatial and temporal landmarks at different temporal resolutions simultaneously. This helps the network efficiently capture both macro-movements (slower pose/arm transitions) and micro-movements (rapid fingerspelling).
# *   **ASR Alignment Techniques (CTC):** Utilizing Connectionist Temporal Classification (CTC) loss, a staple in speech recognition, to better align unsegmented continuous sign streams without requiring tedious frame-level annotations, directly comparing ASR alignment with vision-based sequence modeling.
